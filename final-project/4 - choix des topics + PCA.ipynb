# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import MeanShift
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer

from sklearn.decomposition import NMF
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.datasets import make_multilabel_classification

from sklearn.decomposition import PCA
from joblib import dump, load

from datetime import datetime

# %%
base = pd.read_csv('resultats_google_lemmatises_2005_complet.csv')

# %% [markdown]
# ## Fonction de constitution des topics

# %%
def get_topics(model, n_top_words, nb_clusters):
    #the word ids obtained need to be reverse-mapped to the words so we can print the topic names.
    feat_names = model.named_steps['tfidf'].get_feature_names()
    
    word_dict = {}
    for i in range(nb_clusters):
        
        #for each topic, obtain the largest values, and add the words they map to into the dictionary.
        words_ids = model.named_steps['clust'].components_[i].argsort()[:-30 - 1:-1]
        words = [feat_names[key] for key in words_ids]
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = words
    
    return pd.DataFrame(word_dict)

# %% [markdown]
# ## Application de la fonction pour chacun des modèles, et identification des thèmes qui ressortent
# ### Topics NMF

# %%
for x in range(4,21):
    modele = load('NMF'+str(x)+'.joblib')
    print(get_topics(modele, 10, x))
# Out:
#       Topic # 01      Topic # 02   Topic # 03   Topic # 04
# 0          range       politique  destination      tribune
# 1     suggestion           grand       voyage    chronique
# 2         module           droit     meilleur     appareil
# 3     transition    gouvernement        guide      recette
# 4          promo         service     voyageur         star
# 5          label  internationale        petit      musique
# 6         format      population        plage     rubrique
# 7          event            jour       billet    decodeurs
# 8    automatique        nouvelle      voiture     cultivez
# 9         action          ancien      circuit     poetesse
# 10       message            mort        grand     trilogie
# 11       content    organisation         beau      ignorez
# 12        bumper           civil       agence   mappemonde
# 13        kevlar     information        photo       moment
# 14         probe       militaire        ville    jardinage
# 15         drift         pouvoir         nuit   editoriaux
# 16         noise         dossier       hotels    memorable
# 17    desactivee           homme        carte    fossilise
# 18         jumbo       president     location       renaud
# 19        finish        ministre        offre        aille
# 20        factor       programme      chambre    grammaire
# 21        sample        economie      vacance      passera
# 22          lues         contact        tarif  supplements
# 23    actualisez         million         info  orthographe
# 24          opus          membre     pratique  conjugaison
# 25         octet       nationale          vol       oceans
# 26  experimental           etats         mail    optimiser
# 27          cold        officiel    assurance     banniere
# 28        cobalt           femme        forum  conseillons
# 29      eviction          projet        route     paralyse
#       Topic # 01      Topic # 02   Topic # 03   Topic # 04    Topic # 05
# 0        section           grand  destination      tribune         range
# 1          sport       politique       voyage    chronique    suggestion
# 2          match      population     meilleur     appareil        module
# 3           code  internationale     voyageur      recette    transition
# 4          image    organisation        guide         star         label
# 5           mail    gouvernement        plage      musique         promo
# 6     classement           droit        petit     rubrique        format
# 7     abonnement        officiel       billet    decodeurs         event
# 8           user       nationale      circuit     cultivez   automatique
# 9        abonnez           civil      voiture     poetesse        action
# 10         offre        nouvelle       agence     trilogie        bumper
# 11         promo   developpement         beau      ignorez        kevlar
# 12       archive      territoire       hotels   mappemonde       message
# 13       content         sociale        photo    jardinage         probe
# 14     actualite          projet        grand   editoriaux         drift
# 15           jeu     information         nuit    memorable         noise
# 16  personnelles        habitant        ville    fossilise         jumbo
# 17      magazine          ancien      chambre       renaud    desactivee
# 18         achat           etats        carte    grammaire        finish
# 19          mort          nation     location        aille        factor
# 20        source            zone      vacance       moment        sample
# 21        status       situation        tarif      passera          lues
# 22         video         million        offre  supplements    actualisez
# 23         livre       principal        forum  orthographe          opus
# 24      football         rapport     pratique    optimiser         octet
# 25          logo         secteur          vol       oceans  experimental
# 26   commentaire         service    assurance  conseillons          cold
# 27          data       militaire         info     banniere        cobalt
# 28          date            mise        hotel     paralyse       texture
# 29          lire          centre        route      mesurer      eviction
#      Topic # 01      Topic # 02   Topic # 03   Topic # 04    Topic # 05  \
# 0      vacation       politique  destination      tribune         range
# 1         toast           grand       voyage    chronique    suggestion
# 2      meilleur    gouvernement        petit     appareil        module
# 3       listing           droit        grand      recette    transition
# 4   billetterie  internationale        plage         star         promo
# 5          trip      population     voyageur      musique         label
# 6    attraction         service        guide     rubrique        format
# 7        adulte    organisation     pratique    decodeurs   automatique
# 8          sale           civil       billet     cultivez         event
# 9         tarif       militaire      voiture     poetesse        bumper
# 10   navigateur          ancien    assurance     trilogie        kevlar
# 11        value     information         beau      ignorez         probe
# 12        event            mort        ville   mappemonde         drift
# 13   permission        nouvelle      circuit    jardinage         jumbo
# 14   impression            jour       agence   editoriaux         noise
# 15       module         dossier        carte    memorable    desactivee
# 16         show       president  inspiration    fossilise        factor
# 17   restaurant        ministre        photo       moment          lues
# 18      cuisine           homme       hotels       renaud        finish
# 19       option       nationale     aventure        aille    actualisez
# 20    placement         contact       sejour    grammaire        sample
# 21      chambre         million      vacance      passera          opus
# 22       string         pouvoir      paysage  supplements        action
# 23       direct           etats         parc  orthographe         octet
# 24         nuit        officiel       partir    optimiser  experimental
# 25       promis        economie    transport       oceans          cold
# 26      message      economique      sejours  conjugaison        cobalt
# 27      endroit          nation     montagne     banniere       texture
# 28         mail            chef        hotel  conseillons      eviction
# 29      content         sociale        hiver     paralyse     supprimee
#
#         Topic # 06
# 0         parisien
# 1            jouet
# 2         commande
# 3            match
# 4          section
# 5          affiche
# 6            rugby
# 7            sport
# 8         meilleur
# 9             club
# 10           achat
# 11         manette
# 12       connectee
# 13          marque
# 14      olympiques
# 15          burger
# 16       programme
# 17           vente
# 18        hippisme
# 19      intertitre
# 20        cyclisme
# 21          limite
# 22          tennis
# 23           offre
# 24  electromenager
# 25       bricolage
# 26           promo
# 27        referent
# 28           score
# 29           ratez
#       Topic # 01      Topic # 02   Topic # 03   Topic # 04    Topic # 05  \
# 0        section       politique     vacation      tribune         range
# 1          sport    gouvernement        toast    chronique    suggestion
# 2          match    organisation  billetterie     appareil        module
# 3           code  internationale     meilleur      recette    transition
# 4          image           droit         trip         star         label
# 5     classement      population      listing      musique         promo
# 6          promo           civil   attraction     rubrique        format
# 7     abonnement           grand       adulte    decodeurs   automatique
# 8           mail       nationale         sale     cultivez         event
# 9        abonnez        officiel        tarif     poetesse        bumper
# 10         achat         sociale   permission     trilogie        kevlar
# 11          user   developpement   navigateur      ignorez         probe
# 12           jeu       militaire   impression   mappemonde         drift
# 13         offre          projet       module    jardinage         jumbo
# 14       archive          nation        event   editoriaux         noise
# 15     actualite     information         show    memorable    desactivee
# 16       content        nouvelle        value    fossilise        factor
# 17      magazine        ministre   restaurant       renaud          lues
# 18  personnelles         service      chambre    grammaire    actualisez
# 19         livre          membre    placement        aille        finish
# 20      football       situation       option       moment        sample
# 21        source            mise        forum      passera          opus
# 22          mort         secteur       promis  supplements        action
# 23         video         rapport      cuisine  orthographe         octet
# 24        status      territoire      endroit    optimiser  experimental
# 25          logo         million      message       oceans          cold
# 26   commentaire          public   transition     banniere        cobalt
# 27          lire           homme         nuit  conseillons       texture
# 28      meilleur           etats       picker     paralyse      eviction
# 29      economie         conflit       direct    affichera     supprimee
#
#      Topic # 06      Topic # 07
# 0        voyage          billet
# 1   destination           forum
# 2         petit       assurance
# 3         grand         voiture
# 4         plage         annonce
# 5          beau     inspiration
# 6         ville  materiellement
# 7       circuit     portabilite
# 8      voyageur   referencement
# 9       paysage         routard
# 10     meilleur       consentez
# 11         parc       indemnite
# 12     montagne        hachette
# 13         jour        adequate
# 14        saint        pratique
# 15        carte       partagees
# 16         nuit      conservees
# 17         iles     destination
# 18        guide          mettra
# 19       agence   indemnisation
# 20      village         ecrivez
# 21       nature        publiees
# 22       partir   rectification
# 23       sejour           livre
# 24       saison         ecoutez
# 25         nord        editeurs
# 26         tour    accompagnent
# 27     pratique            saga
# 28         cote         camping
# 29        heure       directive
#       Topic # 01      Topic # 02   Topic # 03   Topic # 04   Topic # 05  \
# 0        section       politique     vacation      tribune        saint
# 1          sport    gouvernement        toast    chronique    argentine
# 2          match      population  billetterie     appareil   philippine
# 3           code  internationale     meilleur      recette       chypre
# 4          image           civil         trip         star        chili
# 5     classement           droit      listing      musique   dominicain
# 6          promo    organisation   attraction     rubrique       panama
# 7          achat           grand       adulte    decodeurs        malte
# 8            jeu       militaire         sale     cultivez        perou
# 9           mail       nationale        tarif     poetesse    allemagne
# 10       abonnez        ministre   permission     trilogie        suede
# 11    abonnement         sociale   navigateur      ignorez       bresil
# 12         offre        officiel   impression   mappemonde        japon
# 13          user          projet       module    jardinage     equateur
# 14       archive          nation        event   editoriaux         inde
# 15       content           homme         show    memorable       suisse
# 16     actualite       president   restaurant    fossilise       canada
# 17      magazine         million      chambre       renaud        arabe
# 18      football   developpement    placement        aille        benin
# 19  personnelles           parti        value    grammaire       ivoire
# 20         livre          guerre       option       moment     belgique
# 21          logo          accord       promis      passera      emirats
# 22        source       situation        forum  supplements     mongolie
# 23      parisien          ancien      cuisine  orthographe        chine
# 24         video         conflit      endroit    optimiser       guinee
# 25        status         pouvoir      message       oceans      tcheque
# 26      meilleur            chef         nuit     banniere     saoudite
# 27   commentaire         secteur   transition  conseillons       sierra
# 28        minute            mise       picker     paralyse         mali
# 29          data         service       direct    affichera  equatoriale
#
#      Topic # 06      Topic # 07    Topic # 08
# 0         petit          billet         range
# 1   destination           forum    suggestion
# 2        voyage       assurance        module
# 3         grand         voiture    transition
# 4         plage     inspiration         label
# 5          beau         annonce         promo
# 6         ville  materiellement        format
# 7       paysage     portabilite   automatique
# 8       circuit   referencement         event
# 9      meilleur         routard        bumper
# 10     montagne       consentez        kevlar
# 11         parc       indemnite         probe
# 12         nuit        hachette         drift
# 13         jour        adequate         jumbo
# 14      village        pratique         noise
# 15     voyageur     destination    desactivee
# 16       nature       partagees        factor
# 17       saison      conservees          lues
# 18         tour          mettra    actualisez
# 19        guide         ecrivez        finish
# 20        carte   indemnisation        sample
# 21       sejour        publiees          opus
# 22        terre           livre         octet
# 23       partir   rectification  experimental
# 24       bateau         ecoutez          cold
# 25   decouverte        editeurs        cobalt
# 26     pratique    accompagnent        action
# 27        heure         camping       texture
# 28       centre            saga      eviction
# 29      sauvage       directive     supprimee
#       Topic # 01      Topic # 02   Topic # 03   Topic # 04   Topic # 05  \
# 0        section       politique        petit      tribune        saint
# 1          image    gouvernement  destination    chronique    argentine
# 2          sport  internationale       voyage     appareil       chypre
# 3           mail    organisation        grand      recette        chili
# 4           user      population        plage         star   philippine
# 5       magazine           droit         beau      musique   dominicain
# 6   personnelles           grand        ville     rubrique       panama
# 7           code           civil      paysage    decodeurs        malte
# 8         status       nationale      circuit     cultivez        perou
# 9          match         sociale     meilleur     poetesse    allemagne
# 10    abonnement        officiel     montagne     trilogie        suede
# 11   commentaire       militaire         parc      ignorez       bresil
# 12         value          projet         nuit   mappemonde        japon
# 13       referer   developpement         jour    jardinage     equateur
# 14          body          nation      village   editoriaux       suisse
# 15      connecte        ministre     voyageur    memorable         inde
# 16        update         secteur       nature    fossilise       canada
# 17          mort          public       saison       renaud        arabe
# 18       content       situation        guide        aille        benin
# 19     actualite         rapport         tour    grammaire      emirats
# 20         slice            mise        carte       moment     belgique
# 21       abonnez           homme       sejour      passera       ivoire
# 22       archive         million        terre  supplements     mongolie
# 23          logo          membre       partir  orthographe        chine
# 24       partage          accord       bateau    optimiser      tcheque
# 25      location         conflit   decouverte       oceans       guinee
# 26     container         pouvoir     pratique  conseillons     saoudite
# 27        string           parti      sauvage     banniere       sierra
# 28        source          guerre       centre     paralyse         mali
# 29    classement       ressource        heure    affichera  equatoriale
#
#         Topic # 06      Topic # 07    Topic # 08   Topic # 09
# 0         parisien          billet         range     vacation
# 1            jouet       assurance    suggestion        toast
# 2         commande           forum        module     meilleur
# 3          affiche         voiture    transition  billetterie
# 4          manette     inspiration         label         trip
# 5             club         annonce         promo   attraction
# 6           marque  materiellement        format      listing
# 7            match     portabilite   automatique       adulte
# 8       intertitre   referencement         event         sale
# 9           limite         routard        bumper        tarif
# 10           achat       consentez        kevlar   permission
# 11        meilleur       indemnite         probe   navigateur
# 12        hippisme        hachette         drift   impression
# 13  electromenager        adequate         jumbo       module
# 14           vente        pratique         noise        event
# 15        referent     destination        factor      chambre
# 16       connectee       partagees    desactivee   restaurant
# 17           rugby      conservees          lues         show
# 18       bricolage          mettra    actualisez    placement
# 19           ratez         ecrivez        sample       option
# 20       programme   indemnisation        finish        value
# 21    immobilieres        publiees          opus       promis
# 22        cyclisme   rectification         octet      cuisine
# 23      olympiques         ecoutez  experimental        forum
# 24           swing           livre          cold      endroit
# 25         section        editeurs        cobalt         nuit
# 26         redoute    accompagnent       texture   transition
# 27           marne         camping      eviction      message
# 28           opter            saga     supprimee       picker
# 29          casque       transport        action       direct
#      Topic # 01      Topic # 02   Topic # 03   Topic # 04    Topic # 05  \
# 0         petit       politique        saint      tribune         range
# 1   destination    gouvernement    argentine    chronique    suggestion
# 2        voyage  internationale       chypre     appareil        module
# 3         grand    organisation        chili      recette    transition
# 4         plage      population   philippine         star         label
# 5          beau           droit   dominicain      musique         promo
# 6         ville           grand       panama     rubrique   automatique
# 7       paysage           civil        malte    decodeurs        format
# 8       circuit       nationale        perou     cultivez         event
# 9      montagne       militaire    allemagne     poetesse        bumper
# 10     meilleur         sociale        suede     trilogie        kevlar
# 11         parc        officiel       bresil      ignorez         probe
# 12         nuit          projet        japon   mappemonde         drift
# 13         jour   developpement     equateur    jardinage         jumbo
# 14      village        ministre         inde   editoriaux         noise
# 15     voyageur          nation       suisse    memorable        factor
# 16       nature         secteur       canada    fossilise    desactivee
# 17       saison          public        arabe       renaud          lues
# 18       sejour       situation        benin        aille    actualisez
# 19       partir         rapport      emirats    grammaire        sample
# 20         tour           homme     belgique       moment          opus
# 21        terre         million       ivoire      passera        finish
# 22       bateau          accord     mongolie  supplements         octet
# 23        carte          membre        chine  orthographe  experimental
# 24   decouverte            mise      tcheque    optimiser          cold
# 25     pratique         conflit       guinee       oceans        cobalt
# 26        guide         pouvoir     saoudite  conseillons       texture
# 27       centre           parti       sierra     banniere      eviction
# 28        heure          guerre         mali     paralyse     supprimee
# 29      sauvage       ressource  equatoriale    affichera        extras
#
#         Topic # 06      Topic # 07    Topic # 08   Topic # 09    Topic # 10
# 0         parisien          billet        revenu     vacation         sport
# 1            jouet       assurance         promo        toast       section
# 2         commande           forum     epilateur  billetterie         image
# 3          affiche         voiture       stretch     meilleur          code
# 4          manette     inspiration         apnee         trip          mail
# 5             club         annonce    extracteur   attraction      magazine
# 6           marque  materiellement    controleur      listing  personnelles
# 7       intertitre     portabilite       pointer       adulte        status
# 8           limite   referencement        figaro         sale       referer
# 9            vente         routard         loyer        tarif      connecte
# 10        hippisme       consentez        brevet   permission   commentaire
# 11  electromenager       indemnite         layer   navigateur         value
# 12        referent        hachette        radius   impression    abonnement
# 13       bricolage        adequate      figurant       module        update
# 14           match        pratique    comparatif        event          user
# 15           ratez     destination         plume      chambre         slice
# 16    immobilieres       partagees     nutrition   restaurant          body
# 17           sport      conservees  encyclopedie         show       archive
# 18        cyclisme          mettra       sommeil    placement       partage
# 19           achat         ecrivez          pack       option        string
# 20         redoute   indemnisation        square        value          mort
# 21           marne        publiees          tuer       promis       dossier
# 22           opter   rectification   transparent        forum      location
# 23           swing         ecoutez         impot      cuisine     publicite
# 24          casque        editeurs        burger      endroit       envoyer
# 25      aspirateur           livre      vertical         nuit         match
# 26          tennis    accompagnent     connectee      message     champagne
# 27          averer         camping         mythe   transition         actif
# 28           alias            saga         edito       picker       mention
# 29            deco       transport      meilleur       direct         video
#      Topic # 01      Topic # 02   Topic # 03   Topic # 04    Topic # 05  \
# 0         petit       politique        saint      tribune         range
# 1   destination    gouvernement    argentine    chronique    suggestion
# 2        voyage           droit       chypre     appareil        module
# 3         grand           civil        chili      recette    transition
# 4         plage    organisation   philippine         star         label
# 5          beau  internationale   dominicain      musique         promo
# 6       paysage           grand       panama     rubrique   automatique
# 7         ville         sociale        malte    decodeurs        format
# 8       circuit        ministre        perou     cultivez         event
# 9      meilleur          projet        suede     poetesse        bumper
# 10     montagne           homme    allemagne     trilogie        kevlar
# 11         parc       militaire       bresil      ignorez         probe
# 12         nuit           parti     equateur   mappemonde         drift
# 13         jour         pouvoir       suisse    jardinage         jumbo
# 14      village         rapport         inde   editoriaux         noise
# 15     voyageur      population        japon    memorable        factor
# 16       nature          public       canada    fossilise    desactivee
# 17       saison          accord        arabe        aille          lues
# 18       sejour       situation        benin       renaud    actualisez
# 19       partir         conflit       ivoire    grammaire        sample
# 20         tour          nation     belgique      passera          opus
# 21     pratique            chef      emirats       moment        finish
# 22   decouverte          membre     mongolie  supplements         octet
# 23       bateau       nationale        chine  orthographe  experimental
# 24        guide          guerre      tcheque    optimiser          cold
# 25      visiter        question       guinee       oceans        cobalt
# 26        heure       president     saoudite  conseillons       texture
# 27     aventure   developpement         mali     banniere      eviction
# 28       soleil          ancien       sierra     paralyse     supprimee
# 29       visite        officiel  equatoriale    affichera        extras
#
#         Topic # 06      Topic # 07    Topic # 08   Topic # 09    Topic # 10  \
# 0         parisien          billet        revenu     vacation         sport
# 1            jouet       assurance         promo        toast       section
# 2         commande           forum     epilateur  billetterie         image
# 3          affiche         voiture       stretch     meilleur          code
# 4          manette     inspiration         apnee         trip          mail
# 5             club         annonce    extracteur   attraction      magazine
# 6           marque  materiellement    controleur      listing  personnelles
# 7       intertitre     portabilite       pointer       adulte        status
# 8           limite   referencement        figaro         sale       referer
# 9            vente         routard         loyer        tarif      connecte
# 10        hippisme       consentez        brevet   permission         value
# 11  electromenager       indemnite         layer   navigateur        update
# 12        referent        hachette        radius   impression   commentaire
# 13           match        adequate      figurant       module          user
# 14       bricolage     destination    comparatif        event         slice
# 15           ratez        pratique         plume   restaurant    abonnement
# 16    immobilieres       partagees     nutrition      chambre        string
# 17           sport      conservees  encyclopedie    placement       partage
# 18        cyclisme          mettra          pack         show          body
# 19           achat         ecrivez       sommeil       option       archive
# 20         redoute   indemnisation        square        value       envoyer
# 21           opter        publiees          tuer       promis     champagne
# 22           marne   rectification         impot        forum      location
# 23           swing         ecoutez   transparent      cuisine         actif
# 24      aspirateur        editeurs        burger      endroit         match
# 25          casque           livre     connectee      message     publicite
# 26          tennis    accompagnent      vertical         nuit          mort
# 27          averer         camping         mythe   transition       dossier
# 28           alias            saga         edito       picker   thematiques
# 29            deco       transport    olympiques       direct        charte
#
#         Topic # 11
# 0        industrie
# 1         habitant
# 2        naissance
# 3       production
# 4         natalite
# 5        infantile
# 6        mortalite
# 7        esperance
# 8             sida
# 9    geographiques
# 10           terre
# 11      croissance
# 12           radio
# 13      prevalence
# 14  transnationaux
# 15       irriguees
# 16         arables
# 17        revetues
# 18     topographie
# 19        exportes
# 20        maritime
# 21     exportation
# 22     demographie
# 23            taux
# 24      asphaltees
# 25      population
# 26       fertilite
# 27   accroissement
# 28        importes
# 29      industriel
#      Topic # 01      Topic # 02  Topic # 03      Topic # 04    Topic # 05  \
# 0   destination        retraite       saint        parisien         range
# 1         petit        chantons   argentine           jouet    suggestion
# 2        voyage      suspendent      chypre        commande        module
# 3         grand          bayard       chili         affiche    transition
# 4         plage         pelerin  philippine         manette         label
# 5          beau       phosphore  dominicain            club         promo
# 6       paysage           prion      panama          marque   automatique
# 7       circuit       reclusion       malte      intertitre        format
# 8         ville        rassures       perou          limite         event
# 9      meilleur  protestantisme       suede           vente        bumper
# 10     montagne        judaisme      bresil        hippisme        kevlar
# 11         parc      orthodoxie   allemagne  electromenager         probe
# 12         nuit         extrade    equateur        referent         drift
# 13         jour    catholicisme        inde           match         jumbo
# 14      village           bible       japon       bricolage         noise
# 15     voyageur          misent      suisse           ratez        factor
# 16       nature         doublee       arabe    immobilieres    desactivee
# 17       saison       fantaisie      canada           sport          lues
# 18       sejour         laicite    belgique        cyclisme    actualisez
# 19       partir      bouddhisme       benin           achat        sample
# 20         tour            haie      ivoire         redoute          opus
# 21   decouverte      rigoureuse     emirats           opter        finish
# 22     pratique        argentin    mongolie           marne         octet
# 23        guide            pape     tcheque           swing  experimental
# 24       bateau      ecosysteme       chine      aspirateur          cold
# 25      visiter           milan      guinee          casque        cobalt
# 26        heure      adolescent    saoudite          tennis       texture
# 27    decouvrir        attentat      sierra          averer      eviction
# 28     aventure      catholique        mali           alias     supprimee
# 29       soleil       diaporama         lao            deco        extras
#
#         Topic # 06      Topic # 07    Topic # 08   Topic # 09    Topic # 10  \
# 0        politique          billet        revenu     vacation         sport
# 1     organisation       assurance         promo        toast       section
# 2     gouvernement           forum     epilateur  billetterie         image
# 3            civil         voiture       stretch     meilleur          code
# 4            droit     inspiration         apnee         trip          mail
# 5   internationale         annonce    extracteur   attraction      magazine
# 6           projet  materiellement    controleur      listing  personnelles
# 7          sociale     portabilite       pointer       adulte        status
# 8            grand   referencement        figaro         sale       referer
# 9           public         routard         loyer        tarif      connecte
# 10         rapport       consentez        brevet   permission         value
# 11   developpement       indemnite         layer   navigateur        update
# 12        ministre        hachette        radius   impression   commentaire
# 13          membre        adequate      figurant       module          user
# 14      population     destination    comparatif        event         slice
# 15           homme        pratique         plume   restaurant    abonnement
# 16       nationale       partagees     nutrition      chambre          body
# 17       situation      conservees  encyclopedie         show       partage
# 18            mise          mettra          pack    placement        string
# 19        officiel         ecrivez       sommeil       option       archive
# 20          nation   indemnisation        square        value       envoyer
# 21        question        publiees          tuer       promis      location
# 22     information   rectification   transparent        forum     champagne
# 23         pouvoir         ecoutez         impot      cuisine         match
# 24          action        editeurs        burger      endroit         actif
# 25         conflit           livre     connectee      message     publicite
# 26       principal    accompagnent      vertical         nuit          mort
# 27           parti         camping         mythe   transition   thematiques
# 28         mission       transport         edito       picker        charte
# 29          accord            saga    olympiques       direct        minute
#
#         Topic # 11   Topic # 12
# 0        industrie      tribune
# 1         habitant    chronique
# 2        naissance     appareil
# 3         natalite      recette
# 4       production         star
# 5        infantile      musique
# 6        mortalite     rubrique
# 7        esperance    decodeurs
# 8             sida     cultivez
# 9    geographiques     poetesse
# 10           terre     trilogie
# 11           radio      ignorez
# 12  transnationaux   mappemonde
# 13      prevalence    jardinage
# 14       irriguees   editoriaux
# 15      croissance    memorable
# 16         arables    fossilise
# 17        revetues       renaud
# 18     topographie        aille
# 19        exportes    grammaire
# 20      asphaltees       moment
# 21     demographie      passera
# 22        maritime  supplements
# 23       fertilite  orthographe
# 24   accroissement    optimiser
# 25        importes       oceans
# 26     exportation  conseillons
# 27    mobilisables     banniere
# 28   conventionnel     paralyse
# 29         fossile    affichera
#         Topic # 01      Topic # 02  Topic # 03      Topic # 04    Topic # 05  \
# 0        champagne        retraite       saint        parisien         range
# 1            champ        chantons   argentine           jouet    suggestion
# 2       abonnement      suspendent      chypre        commande        module
# 3         exclusif          bayard       chili         affiche    transition
# 4         rubrique         pelerin  philippine         manette         label
# 5          dossier       phosphore  dominicain            club         promo
# 6            sport           prion      panama          marque        format
# 7          contenu       reclusion       malte      intertitre   automatique
# 8         archivez        rassures       perou          limite         event
# 9   kinesitherapie  protestantisme       suede        hippisme        bumper
# 10          tesson        judaisme      bresil           vente        kevlar
# 11           logue      orthodoxie   allemagne           match         probe
# 12          cuvees         extrade    equateur  electromenager         drift
# 13   irresistibles    catholicisme       japon        referent         jumbo
# 14     generaliste           bible        inde           sport         noise
# 15      astronomie          misent      suisse       bricolage        factor
# 16        vigneron         doublee       arabe           ratez    desactivee
# 17      identifiez       fantaisie      canada    immobilieres          lues
# 18            anon         laicite    belgique        cyclisme    actualisez
# 19          degree      bouddhisme       benin           achat        sample
# 20    arborescence            haie      ivoire         redoute          opus
# 21            mail      rigoureuse     emirats           opter        finish
# 22          tentez        argentin    mongolie           marne         octet
# 23           gerez            pape     tcheque           swing  experimental
# 24           creez      ecosysteme       chine          tennis          cold
# 25         moderee        attentat      guinee      aspirateur        cobalt
# 26        palmares           milan    saoudite          casque       texture
# 27           bulle      adolescent      sierra           alias      eviction
# 28      autrichien       diaporama        mali          averer     supprimee
# 29       remporter      catholique         lao            deco        extras
#
#         Topic # 06      Topic # 07    Topic # 08   Topic # 09     Topic # 10  \
# 0        politique          billet        revenu     vacation          value
# 1     organisation       assurance         promo        toast        section
# 2     gouvernement           forum     epilateur  billetterie           code
# 3            civil         voiture       stretch     meilleur         minute
# 4            droit     inspiration         apnee         trip      horoscope
# 5   internationale         annonce    extracteur   attraction         puzzle
# 6           projet  materiellement       pointer       adulte        visitee
# 7          sociale     portabilite    controleur      listing        libelle
# 8            grand   referencement        figaro         sale      solitaire
# 9           public         routard         loyer        tarif    commentaire
# 10         rapport       consentez        brevet   permission      certifiee
# 11        ministre       indemnite         layer   navigateur       vignette
# 12           homme        hachette        radius   impression          image
# 13      population        adequate      figurant       module         serial
# 14          membre        pratique    comparatif        event        croises
# 15   developpement     destination         plume   restaurant        fleches
# 16       nationale       partagees     nutrition      chambre  frequentation
# 17       situation      conservees  encyclopedie    placement        choisis
# 18            mise          mettra          pack         show       choisies
# 19        officiel         ecrivez       sommeil       option        mensuel
# 20         pouvoir   indemnisation        square        value     precedents
# 21          nation        publiees          tuer       promis         insert
# 22        question   rectification         impot        forum     caracteres
# 23          action         ecoutez   transparent      endroit   illustration
# 24     information        editeurs        burger      cuisine        referer
# 25         conflit           livre      vertical      message          agent
# 26       principal    accompagnent     connectee         nuit       gratuits
# 27           parti         camping      meilleur       picker          panel
# 28          accord            saga         edito   transition   personnelles
# 29         mission       transport         mythe       direct      retourner
#
#         Topic # 11   Topic # 12   Topic # 13
# 0        industrie      tribune  destination
# 1         habitant    chronique        petit
# 2        naissance     appareil       voyage
# 3         natalite      recette        grand
# 4       production         star        plage
# 5        infantile      musique         beau
# 6        mortalite     rubrique      paysage
# 7        esperance    decodeurs      circuit
# 8             sida     cultivez        ville
# 9    geographiques     poetesse     meilleur
# 10           terre     trilogie     montagne
# 11           radio      ignorez         parc
# 12  transnationaux   mappemonde         nuit
# 13      prevalence    jardinage         jour
# 14      croissance   editoriaux      village
# 15       irriguees    memorable     voyageur
# 16         arables    fossilise       nature
# 17        revetues       renaud       saison
# 18     topographie        aille       sejour
# 19        exportes    grammaire         tour
# 20        maritime       moment       partir
# 21      asphaltees      passera   decouverte
# 22     demographie  supplements     pratique
# 23       fertilite  orthographe       bateau
# 24     exportation    optimiser        guide
# 25   accroissement       oceans      visiter
# 26        importes  conseillons    decouvrir
# 27    mobilisables     banniere        heure
# 28   conventionnel     paralyse     aventure
# 29            taux    affichera       soleil
#         Topic # 01      Topic # 02  Topic # 03      Topic # 04    Topic # 05  \
# 0        champagne        retraite       saint        parisien        format
# 1            champ        chantons   argentine           jouet  hebdomadaire
# 2         exclusif      suspendent      chypre        commande         match
# 3         rubrique          bayard       chili         affiche        abonne
# 4          dossier         pelerin  philippine         manette       abonnez
# 5         archivez       phosphore  dominicain            club       replace
# 6   kinesitherapie           prion       malte          marque       premium
# 7           tesson       reclusion      panama      intertitre    abonnement
# 8            logue        rassures       perou          limite        lambda
# 9       abonnement  protestantisme       suede           vente         theta
# 10          cuvees        judaisme      bresil        hippisme         regie
# 11   irresistibles      orthodoxie   allemagne  electromenager        status
# 12     generaliste         extrade    equateur        referent         kappa
# 13      astronomie    catholicisme       japon       bricolage          iota
# 14        vigneron           bible        inde           ratez        strict
# 15            anon          misent      suisse    immobilieres         offre
# 16           sport         doublee      canada           sport         perso
# 17    arborescence       fantaisie       arabe           match         alpha
# 18          degree         laicite    belgique        cyclisme     decouvrez
# 19           gerez      bouddhisme       benin           achat     dimension
# 20          tentez            haie     emirats         redoute      magazine
# 21         moderee      rigoureuse      ivoire           opter        lycees
# 22           bulle        argentin    mongolie           marne       percent
# 23         contenu            pape     tcheque           swing       exercer
# 24        palmares      ecosysteme       chine      aspirateur        papier
# 25       remporter           milan      guinee          casque   telechargez
# 26      autrichien      adolescent    saoudite          tennis          pave
# 27           ancre      catholique      sierra          averer       expires
# 28            mail       diaporama        mali            deco         style
# 29         detecte    conservateur         lao           alias  personnelles
#
#         Topic # 06      Topic # 07    Topic # 08   Topic # 09     Topic # 10  \
# 0     organisation          billet         range     vacation         minute
# 1        politique       assurance    suggestion        toast          value
# 2            civil           forum        module  billetterie        visitee
# 3     gouvernement         voiture    transition     meilleur         puzzle
# 4   internationale     inspiration         label         trip    commentaire
# 5           projet         annonce         promo   attraction        libelle
# 6          sociale  materiellement   automatique       adulte      horoscope
# 7            droit     portabilite        format      listing      solitaire
# 8           public   referencement         event         sale       vignette
# 9    developpement         routard        bumper        tarif        section
# 10         rapport       consentez        kevlar   permission      certifiee
# 11           grand       indemnite         probe   navigateur           code
# 12     information        hachette         drift   impression        croises
# 13          membre        adequate         jumbo       module        fleches
# 14            mise     destination         noise        event        choisis
# 15        officiel        pratique    desactivee   restaurant       choisies
# 16       situation       partagees        factor      chambre  frequentation
# 17       nationale      conservees          lues    placement     precedents
# 18          nation          mettra    actualisez         show        mensuel
# 19        question         ecrivez        sample       option     caracteres
# 20        ministre   indemnisation          opus        value   illustration
# 21         mission        publiees        finish       promis          panel
# 22           homme   rectification         octet        forum         serial
# 23          action         ecoutez  experimental      cuisine        listing
# 24      population        editeurs          cold      endroit      retourner
# 25        objectif           livre        cobalt      message   consentement
# 26        relation    accompagnent       texture         nuit       gratuits
# 27         conflit         camping      eviction       picker   localisation
# 28       formation       transport     supprimee   transition         insert
# 29         pouvoir            saga        extras       direct    precedentes
#
#         Topic # 11   Topic # 12   Topic # 13    Topic # 14
# 0        industrie      tribune  destination        revenu
# 1         habitant    chronique        petit         promo
# 2        naissance     appareil       voyage     epilateur
# 3         natalite      recette        grand       stretch
# 4       production         star        plage         apnee
# 5        infantile      musique         beau    extracteur
# 6        mortalite     rubrique      paysage    controleur
# 7        esperance    decodeurs      circuit       pointer
# 8             sida     cultivez        ville        figaro
# 9            terre     poetesse     montagne         loyer
# 10   geographiques     trilogie     meilleur        brevet
# 11           radio      ignorez         parc         layer
# 12  transnationaux   mappemonde         nuit      figurant
# 13      prevalence    jardinage      village        radius
# 14       irriguees   editoriaux         jour    comparatif
# 15         arables    memorable     voyageur         plume
# 16        revetues    fossilise       nature     nutrition
# 17     topographie       renaud       saison  encyclopedie
# 18        exportes        aille       sejour       sommeil
# 19      croissance    grammaire         tour          pack
# 20      asphaltees       moment       partir        square
# 21     demographie      passera   decouverte   transparent
# 22        maritime  supplements       bateau          tuer
# 23       fertilite  orthographe     pratique         impot
# 24   accroissement    optimiser        guide     connectee
# 25        importes       oceans      visiter        burger
# 26    mobilisables  conseillons    decouvrir      vertical
# 27   conventionnel     banniere      sauvage         mythe
# 28         fossile     paralyse       soleil    olympiques
# 29     exportation    affichera        heure         rugby
# ...
# 2            visa       assurance        click  billetterie         puzzle
# 3        consulat         voiture         body     meilleur      solitaire
# 4         conseil     inspiration         data      listing      horoscope
# 5          public         annonce      content         trip        section
# 6     information  materiellement        class   attraction        libelle
# 7      consulaire     portabilite         show         sale      certifiee
# 8     consulaires   referencement      contact       adulte       vignette
# 9         urgence         routard         info   permission          value
# 10    vaccination       consentez        input        tarif        fleches
# 11        service       indemnite        value   impression        croises
# 12          civil        hachette       option   navigateur       choisies
# 13       pratique        adequate         ajax      chambre        choisis
# 14       voyageur       partagees     location       module  frequentation
# 15      ministere      conservees       action   restaurant     precedents
# 16     etrangeres          mettra        catch    placement           code
# 17        mission         ecrivez       mobile       promis        mensuel
# 18        maladie   indemnisation      message      cuisine    commentaire
# 19       etranger     destination         test      endroit        listing
# 20        etudier        publiees         date         nuit     caracteres
# 21   legalisation   rectification         open   transition      retourner
# 22       registre         ecoutez         type        forum          panel
# 23       annuaire           livre         auto        motel   illustration
# 24       notariat        pratique  information        cheap      parametre
# 25      passeport        editeurs        image       pondez   consentement
# 26        affaire    accompagnent  commentaire    explorera   localisation
# 27      augmenter            saga    container      encoder         insert
# 28       imprimer         camping        close      hydrate           mark
# 29  collectivites       directive         none       picker       gratuits
#
#         Topic # 11   Topic # 12    Topic # 13    Topic # 14      Topic # 15  \
# 0        industrie      tribune     commander        revenu       champagne
# 1         habitant    chronique          desk         promo        exclusif
# 2        naissance     appareil      apprenez     epilateur           champ
# 3       production      recette  hebdomadaire       stretch        rubrique
# 4         natalite         star         queue         apnee        archivez
# 5        infantile      musique     annonceur    extracteur  kinesitherapie
# 6        mortalite     rubrique       abonnes    controleur          tesson
# 7        esperance    decodeurs      fracture         loyer           logue
# 8             sida     cultivez        abonne        brevet          cuvees
# 9            terre     poetesse       abonnez        figaro   irresistibles
# 10           radio     trilogie   abandonnees         layer         dossier
# 11   geographiques      ignorez         gilet      figurant      astronomie
# 12  transnationaux   mappemonde     connexion    comparatif     generaliste
# 13       irriguees    jardinage       sentent         plume        vigneron
# 14         arables   editoriaux      argument     nutrition            anon
# 15        revetues    memorable    accessoire       sommeil    arborescence
# 16     topographie    fossilise       lecture  encyclopedie          tentez
# 17        exportes        aille        master        square           gerez
# 18      prevalence       renaud     mondiales          pack         moderee
# 19      croissance    grammaire    inegalites          tuer      abonnement
# 20      asphaltees      passera      complete         impot           bulle
# 21     demographie  supplements         offre       pointer       remporter
# 22       fertilite  orthographe        reagir     connectee      autrichien
# 23    mobilisables       moment       revient        radius         detecte
# 24   accroissement    optimiser         creez        burger           ancre
# 25        importes       oceans    abonnement    olympiques          degree
# 26   conventionnel  conseillons       replace         mythe       completer
# 27         fossile     paralyse         break   transparent           sport
# 28          pavees     banniere        status         flush  identification
# 29        maritime    affichera        rester         edito      identifiez
#
#    Topic # 16      Topic # 17   Topic # 18   Topic # 19
# 0        yuan        retraite      roumain       chypre
# 1       xiang        chantons     polonais    argentine
# 2        tong      suspendent     hongrois        chili
# 3        yang          bayard      bulgare   philippine
# 4        chou         pelerin    lituanien   dominicain
# 5        fang       phosphore       danois       panama
# 6        gong           prion     estonien        malte
# 7        ding       reclusion       croate        saint
# 8        tian        rassures      italien        perou
# 9       adobe  protestantisme       letton        suede
# 10       gang        judaisme         turc     equateur
# 11       dong      orthodoxie     slovaque       bresil
# 12       bing         extrade   vietnamien        japon
# 13       pian    catholicisme        serbe         inde
# 14       song          misent         grec        benin
# 15       bang           bible     allemand      emirats
# 16       ming         doublee      suedois       ivoire
# 17       chao       fantaisie    portugais    allemagne
# 18       juan         laicite      finnois     mongolie
# 19       kids            haie    islandais        arabe
# 20       miao      rigoureuse      slovene       canada
# 21       chai      bouddhisme  neerlandais       suisse
# 22       page      ecosysteme        hindi     belgique
# 23       long        argentin     espagnol       guinee
# 24       rang            pape     japonais        chine
# 25       bold           milan    ukrainien     saoudite
# 26       cyan      adolescent       coreen      tcheque
# 27  distiller       diaporama        russe       sierra
# 28       info         reperes     albanais         mali
# 29       sang       graphique         thai  equatoriale
#       Topic # 01      Topic # 02   Topic # 03      Topic # 04    Topic # 05  \
# 0        support       politique        event        parisien         range
# 1     prospectif    organisation         mail           jouet    suggestion
# 2           vine           grand        click        commande        module
# 3        losange    gouvernement         body         manette    transition
# 4          truck         conflit         data         affiche         label
# 5         calque         sociale      content            club         promo
# 6          diapo           parti        class      intertitre        format
# 7          glass          guerre         show          limite         event
# 8           dock           droit      contact          marque        bumper
# 9         relire          projet        input  electromenager        kevlar
# 10    rejoignant  internationale         info           vente         probe
# 11        format         pouvoir        value        referent         drift
# 12     constants      population       option       bricolage         jumbo
# 13         ruban        objectif         ajax           ratez         noise
# 14           bat          ancien       action           achat    desactivee
# 15     generique          nation        catch        hippisme        factor
# 16        tirage           homme       mobile    immobilieres          lues
# 17     illimitee            chef     location           match          opus
# 18        bouger       situation      message           opter    actualisez
# 19    feuilleter           civil         test         redoute        finish
# 20      vigilant          accord         open      aspirateur         octet
# 21       because          annees         date           marne  experimental
# 22      exigeant         rapport  information          casque        cobalt
# 23  progressiste       nationale         auto          averer       texture
# 24      constant            mise         type           swing          cold
# 25    contribuez          partie        image   reconditionne        sample
# 26      offertes           terme  commentaire            deco      eviction
# 27      depeches          membre    container      disposerez     supprimee
# 28       section      territoire        close    puericulture        extras
# 29   journalisme           jeune         post           alias       passive
#
#        Topic # 06      Topic # 07    Topic # 08   Topic # 09     Topic # 10  \
# 0       ambassade          billet         match     vacation         minute
# 1        officiel           forum        format        toast        visitee
# 2            visa       assurance         theta  billetterie         puzzle
# 3        consulat         voiture        lambda     meilleur      solitaire
# 4         conseil     inspiration         kappa      listing      horoscope
# 5          public         annonce          iota         trip        libelle
# 6     information  materiellement         regie   attraction      certifiee
# 7      consulaire     portabilite         perso         sale       vignette
# 8     consulaires   referencement         alpha       adulte        section
# 9         urgence         routard       percent   permission          value
# 10    vaccination       consentez        lycees        tarif        fleches
# 11        service       indemnite   telechargez   impression        croises
# 12          civil        hachette     detection   navigateur       choisies
# 13       pratique        adequate       exercer      chambre        choisis
# 14       voyageur       partagees       express       module  frequentation
# 15      ministere      conservees   selectionne   restaurant     precedents
# 16     etrangeres          mettra          pave    placement           code
# 17        mission         ecrivez         trial      cuisine        mensuel
# 18        maladie   indemnisation  publicitaire       promis    commentaire
# 19       etranger     destination  hebdomadaire      endroit        listing
# 20        etudier        publiees    expiration         nuit     caracteres
# 21   legalisation   rectification      conteste   transition      retourner
# 22       registre         ecoutez          vide        forum          panel
# 23       annuaire        pratique    resolution        motel   illustration
# 24       notariat        editeurs        strict        cheap      parametre
# 25      passeport           livre         natif       pondez   consentement
# 26        affaire    accompagnent         phone    explorera       gratuits
# 27    nationalite            saga     permettra      encoder   localisation
# 28  collectivites         camping      tendance      hydrate           mark
# 29      augmenter       directive       referer       picker    precedentes
#
#         Topic # 11   Topic # 12   Topic # 13    Topic # 14      Topic # 15  \
# 0        industrie      tribune  destination        revenu       champagne
# 1         habitant    chronique       voyage         promo        exclusif
# 2        naissance     appareil        petit     epilateur           champ
# 3       production      recette        plage       stretch        rubrique
# 4         natalite         star         beau         apnee        archivez
# 5        infantile      musique        grand    extracteur  kinesitherapie
# 6        mortalite     rubrique      circuit    controleur          tesson
# 7        esperance    decodeurs      paysage         loyer           logue
# 8             sida     cultivez        ville        brevet          cuvees
# 9            terre     poetesse         parc        figaro   irresistibles
# 10           radio     trilogie     montagne         layer         dossier
# 11   geographiques      ignorez     meilleur      figurant      astronomie
# 12  transnationaux   mappemonde         nuit    comparatif     generaliste
# 13       irriguees    jardinage      village         plume        vigneron
# 14         arables   editoriaux       nature     nutrition            anon
# 15        revetues    memorable         jour       sommeil    arborescence
# 16     topographie    fossilise     voyageur  encyclopedie          tentez
# 17        exportes        aille        guide        square           gerez
# 18      prevalence       renaud       sejour          pack         moderee
# 19      croissance    grammaire         tour          tuer      abonnement
# 20      asphaltees      passera       saison         impot           bulle
# 21     demographie  supplements       bateau       pointer       remporter
# 22       fertilite  orthographe      sauvage     connectee      autrichien
# 23    mobilisables       moment       visite        radius         detecte
# 24   accroissement    optimiser   decouverte        burger           ancre
# 25        importes       oceans        envie    olympiques          degree
# 26   conventionnel  conseillons       partir         mythe       completer
# 27         fossile     paralyse       soleil   transparent  identification
# 28          pavees     banniere        terre         flush           sport
# 29        maritime    affichera      visiter         edito      identifiez
#
#    Topic # 16      Topic # 17   Topic # 18   Topic # 19    Topic # 20
# 0        yuan        retraite      roumain       chypre          desk
# 1       xiang        chantons     polonais    argentine      apprenez
# 2        tong      suspendent     hongrois        chili  hebdomadaire
# 3        yang          bayard      bulgare   philippine     annonceur
# 4        chou         pelerin    lituanien   dominicain      fracture
# 5        fang       phosphore       danois       panama   abandonnees
# 6        gong           prion     estonien        malte       sentent
# 7        ding       reclusion       croate        saint    accessoire
# 8        tian        rassures      italien        perou        master
# 9       adobe  protestantisme       letton        suede         gilet
# 10       gang        judaisme         turc     equateur     mondiales
# 11       dong      orthodoxie     slovaque       bresil    inegalites
# 12       bing         extrade   vietnamien        japon         creez
# 13       pian    catholicisme        serbe         inde        reagir
# 14       song          misent         grec        benin      gratuits
# 15       bang           bible     allemand      emirats       revient
# 16       ming         doublee      suedois       ivoire         break
# 17       chao       fantaisie      finnois    allemagne     commander
# 18       juan         laicite    portugais     mongolie        rester
# 19       kids            haie    islandais        arabe      courrier
# 20       miao      rigoureuse      slovene       canada          best
# 21       chai      bouddhisme  neerlandais       suisse      visiteur
# 22       page      ecosysteme        hindi     belgique     catalogne
# 23       long        argentin     japonais       guinee         jaune
# 24       rang            pape     espagnol        chine    discussion
# 25       bold           milan    ukrainien     saoudite       premium
# 26       cyan      adolescent       coreen      tcheque       recevez
# 27  distiller       diaporama        russe       sierra        series
# 28       info         reperes     albanais         mali        border
# 29       sang       graphique         thai  equatoriale      profiter

# %%
topic_NMF_tourisme = [('NMF4',2),('NMF5',2),('NMF6',2),('NMF7',5),('NMF8',5),('NMF9',2),('NMF10',0),('NMF11',0),('NMF12',0),
                   ('NMF13',12),('NMF14',12),('NMF15',12),('NMF16',12),('NMF17',15),('NMF18',2),('NMF19',2),('NMF20',12)]
topic_NMF_reservations = [('NMF7',2),('NMF8',2),('NMF9',8),('NMF10',8),('NMF11',8),('NMF12',8),('NMF13',8),('NMF14',8),('NMF15',8),('NMF16',8),
                     ('NMF17',8),('NMF18',8),('NMF19',8),('NMF20',8)]
topic_NMF_guides = [('NMF7',6),('NMF8',6),('NMF9',6),('NMF10',6),('NMF11',6),('NMF12',6),('NMF13',6),('NMF14',6),('NMF15',6),('NMF16',6),
               ('NMF17',6),('NMF18',6),('NMF19',6),('NMF20',6)]
topic_NMF_consulat = [('NMF17',5),('NMF19',5),('NMF20',5)]
topic_NMF_politique = [('NMF4',1),('NMF5',1),('NMF6',1),('NMF7',1),('NMF8',1),('NMF9',1),('NMF10',1),('NMF11',1),('NMF12',5),('NMF13',5)
                  ,('NMF14',5),('NMF15',5),('NMF16',5),('NMF17',1),('NMF18',1),('NMF19',1),('NMF20',1)]
topic_NMF_religion = [('NMF13',1),('NMF14',1),('NMF15',1),('NMF16',1),('NMF17',16),('NMF18',16),('NMF19',16),('NMF20',16)]
topic_NMF_stats =[('NMF11',10),('NMF12',10),('NMF13',10),('NMF14',10),('NMF15',10),('NMF16',10),('NMF17',10),('NMF18',10),('NMF19',10),('NMF20',10)]

# %% [markdown]
# ### Topics LDA

# %%
for x in range(4,21):
    modele = load('LDA'+str(x)+'.joblib')
    print(get_topics(modele, 10, x))
# Out:
#      Topic # 01      Topic # 02 Topic # 03      Topic # 04
# 0        voyage        parisien       yuan           grand
# 1   destination           jouet      xiang       politique
# 2         petit         manette       yang         service
# 3         grand        commande       tong            jour
# 4         guide      intertitre       chou           droit
# 5         plage  electromenager       fang           image
# 6          beau        referent       gong        nouvelle
# 7         ville           ratez       ding            type
# 8         photo          averer       tian     information
# 9      voyageur       bricolage      adobe            mort
# 10     meilleur      aspirateur       dong            date
# 11        event        hippisme       gang         contact
# 12      circuit    immobilieres       ming    gouvernement
# 13         info           opter       pian            mail
# 14        carte         redoute       song           homme
# 15        image           rater       chao           sport
# 16       partir    puericulture       bang  internationale
# 17        route            deco       bing          ancien
# 18      voiture         inactif       juan         legales
# 19       hotels         jouable       kids         mention
# 20      message        proposee       miao          groupe
# 21         nuit           marne       chai      population
# 22         jour      disposerez       page          source
# 23       billet           swing       rang   international
# 24      content        cloturer       long        economie
# 25        label      connectees       cyan         archive
# 26       agence   reconditionne       bold            plan
# 27   suggestion           alias  distiller           livre
# 28     location          optant    prefixe        location
# 29       locale          livrer       sang      entreprise
#      Topic # 01      Topic # 02     Topic # 03      Topic # 04  \
# 0        voyage        parisien        prefixe           grand
# 1   destination           jouet          tarif       politique
# 2         petit         manette     telephoner         service
# 3         grand        commande        cocarde            jour
# 4         guide      intertitre       composez           image
# 5         plage        referent        virtuel           droit
# 6          beau  electromenager     economisez            type
# 7         ville           ratez       habituel        nouvelle
# 8         photo          averer     habituelle     information
# 9      voyageur       bricolage      indicatif            date
# 10     meilleur        hippisme        appelez            mail
# 11      circuit    immobilieres      operateur         contact
# 12        event           opter       comparez            mort
# 13         info      aspirateur     comparatif    gouvernement
# 14        carte         redoute   telephonique           homme
# 15       partir           rater        appeler           sport
# 16        route         inactif     fonctionne  internationale
# 17       hotels            deco     operateurs          ancien
# 18      voiture        proposee        facture         mention
# 19         nuit           marne       portable         legales
# 20       billet          casque       proposes          groupe
# 21        image           swing   conversation          source
# 22      message           alias     angleterre   international
# 23         jour          livrer           fixe      population
# 24        label         jouable  immediatement        economie
# 25       agence    puericulture  correspondant        location
# 26   suggestion      disposerez          allez            plan
# 27       locale        proverbe         orange         archive
# 28     montagne   reconditionne     ordinateur         contenu
# 29      content        cloturer          siege        position
#
#            Topic # 05
# 0             butagaz
# 1            suggerez
# 2            patinage
# 3              karate
# 4          breakdance
# 5           criterium
# 6          skateboard
# 7           bobsleigh
# 8             curling
# 9            biathlon
# 10        recupererez
# 11         adrenaline
# 12        acrobatique
# 13               judo
# 14               luge
# 15            maillet
# 16          alpinisme
# 17  gravitationnelles
# 18             rallye
# 19          naviguiez
# 20            ecuries
# 21          corrobora
# 22            antonin
# 23         subjonctif
# 24              greco
# 25              alpin
# 26                ski
# 27             jobard
# 28      metallisation
# 29               surf
#      Topic # 01      Topic # 02     Topic # 03      Topic # 04  \
# 0        voyage        parisien        prefixe           grand
# 1   destination           jouet          tarif       politique
# 2         petit        commande     telephoner         service
# 3         guide         manette       composez            jour
# 4         plage      intertitre        virtuel           droit
# 5         grand        referent       habituel           image
# 6          beau  electromenager     economisez        nouvelle
# 7         ville           ratez     habituelle            type
# 8         photo          averer      indicatif     information
# 9      voyageur        hippisme        appelez            date
# 10      circuit       bricolage      operateur         contact
# 11        event           opter       comparez            mort
# 12     meilleur    immobilieres   telephonique            mail
# 13         info         redoute     comparatif    gouvernement
# 14       partir      aspirateur        appeler          ancien
# 15        carte        proposee     fonctionne           homme
# 16       hotels           rater     operateurs  internationale
# 17        image          casque        facture           sport
# 18      voiture           marne       portable          source
# 19       billet            deco       proposes      population
# 20         nuit         affiche   conversation         mention
# 21        route           swing     angleterre         legales
# 22        label          livrer           fixe          groupe
# 23      content           alias  immediatement   international
# 24       agence        proverbe  correspondant        economie
# 25   suggestion         jouable          allez           petit
# 26      message      disposerez         orange        location
# 27      vacance   reconditionne     ordinateur            plan
# 28         jour    puericulture          siege         archive
# 29         parc    interessante          devez        position
#
#          Topic # 05      Topic # 06
# 0          suggerez            yuan
# 1             lotta           xiang
# 2         associons            tong
# 3           defende            yang
# 4   inaccessibilite            chou
# 5           publico            fang
# 6           reforma            gong
# 7              vote            ding
# 8      travailleuse           adobe
# 9     inaccessibles            tian
# 10         exprimes            gang
# 11          defendu            dong
# 12           contra            pian
# 13            forma            ming
# 14        demandons            song
# 15             bill            bing
# 16       hypotheses            chao
# 17          meeting            bang
# 18           minuit            juan
# 19             alle            kids
# 20           reunis            miao
# 21             para            chai
# 22         italiano            long
# 23            staff            page
# 24            heure            rang
# 25             book            info
# 26          pension  transnationaux
# 27      travailleur        revetues
# 28        assemblee       irriguees
# 29          retrait     topographie
#      Topic # 01     Topic # 02     Topic # 03      Topic # 04     Topic # 05  \
# 0   destination  centrifugeuse        prefixe           grand    recupererez
# 1        voyage        placard          tarif       politique     flatulence
# 2         petit      concombre     telephoner         service    appendicite
# 3         plage        carotte       composez            jour      naviguiez
# 4         grand       apportez        virtuel           image         buccal
# 5          beau         goutte      indicatif           droit       margelle
# 6       circuit       terminal       habituel            type  metallisation
# 7         ville         causer     economisez            date        cafeine
# 8      voyageur      varicelle     habituelle            mail      estampage
# 9         guide    articulaire        appelez        nouvelle    crepuscules
# 10       hotels         broyes      operateur     information  thermoformage
# 11       billet          smash       comparez         contact    pavoisement
# 12     meilleur         menthe     comparatif            mort        mouture
# 13      paysage        sideral   telephonique           sport       embrumee
# 14      voiture       obstruer        appeler        location         muguet
# 15         parc          laver     fonctionne          source         petale
# 16        carte        proline     operateurs           homme        genuine
# 17     pratique     centrifuge        facture    gouvernement         greffe
# 18        photo         sorbet       portable          ancien         ourlet
# 19     montagne        genants       proposes         mention          emaux
# 20         nuit         purees   conversation         legales        mazurka
# 21      vacance     processeur     angleterre  internationale       prunelle
# 22       agence        obstrue           fixe          action        lavande
# 23       sejour         broyer  immediatement          groupe         vanner
# 24       partir           kart  correspondant   international        vanneur
# 25     aventure     contenance          allez        position        vantail
# 26    assurance        brocoli         orange            plan        vantard
# 27        hotel      carambole     ordinateur         contenu         ivraie
# 28        route          tamis          siege      population      vaporiser
# 29         jour        capteur          devez            code   vaporisation
#
#        Topic # 06   Topic # 07
# 0            yuan        range
# 1           xiang   suggestion
# 2            tong       module
# 3            yang   transition
# 4            chou        promo
# 5            fang        label
# 6            gong         mime
# 7           adobe    visionner
# 8            tian  automatique
# 9            ding       tester
# 10           gang   multiplier
# 11           dong       format
# 12           pian       fusion
# 13           song       finish
# 14           ming        noise
# 15           chao        probe
# 16           bing       manage
# 17           juan       kevlar
# 18           bang        drift
# 19       natalite       sample
# 20           kids       bumper
# 21      infantile        jumbo
# 22           miao        event
# 23      mortalite      message
# 24           chai       factor
# 25           sida     regarder
# 26      esperance        octet
# 27           long         lues
# 28           page         opus
# 29  geographiques   actualisez
#      Topic # 01        Topic # 02    Topic # 03      Topic # 04   Topic # 05  \
# 0   destination      synthetiques       cocarde           grand     patinage
# 1        voyage          metrique       inversa       politique      butagaz
# 2         petit         infection   centraliser         service     biathlon
# 3         plage         ponctuels       mesurez            jour  acrobatique
# 4         grand          rougeole    engraisses           image     suggerez
# 5       circuit              aire     lactation           droit         judo
# 6          beau        periodique     miniature            type    criterium
# 7      voyageur        mammiferes      plaquent            date   breakdance
# 8         guide          compteur       robuste        nouvelle      curling
# 9         ville     topographique         tiqua            mail   skateboard
# 10       hotels           parlees    gouvernail     information       karate
# 11        carte         fecondite         lippu         contact    bobsleigh
# 12       billet          natalite         nouai        location       rallye
# 13      paysage         infantile      ramoneur            mort  recupererez
# 14     montagne             polar    gaspillent         content   adrenaline
# 15         parc           rentree  detourneront          ancien         luge
# 16     pratique          routiere     nougatine          source        alpin
# 17      voiture   alphabetisation      reglette           sport       hockey
# 18     meilleur     centrifugeuse       obverse           homme    alpinisme
# 19        photo         mortalite   maussaderie         mention     handball
# 20       sejour          createur  maussadement          action      masters
# 21       agence           placard   caramelisee         legales     nordique
# 22      vacance  environnementale         palet        position         surf
# 23    assurance         concombre    torrefiees          groupe         jeep
# 24         nuit        internaute      enrobees    gouvernement        greco
# 25     aventure          urbaines    petillants   international          ski
# 26       partir           carotte        seyant  internationale      maillet
# 27        route          vocation      guimauve         contenu       aviron
# 28         iles              sida     methylene            plan     tactique
# 29        hotel             biais    invertebre           petit      antonin
#
#         Topic # 06      Topic # 07    Topic # 08
# 0        champagne           jouet         range
# 1         archivez        parisien    suggestion
# 2   kinesitherapie        commande        module
# 3           cuvees         manette    transition
# 4           tesson      aspirateur         label
# 5            logue      intertitre         promo
# 6         vigneron      disposerez   automatique
# 7    irresistibles   reconditionne        format
# 8      generaliste    puericulture        finish
# 9       astronomie         jouable         noise
# 10          tentez      surchauffe         probe
# 11            anon        cloturer        kevlar
# 12           gerez        chaudron         drift
# 13         moderee         liseuse        bumper
# 14         detecte          optant         jumbo
# 15    arborescence  electromenager          lues
# 16       remporter            lego        factor
# 17           bulle       eligibles        sample
# 18      renseignez        referent         event
# 19         achetez       reveillon         octet
# 20           ancre         affiche    actualisez
# 21          madere     marseillais          opus
# 22        exclusif            nerf      eviction
# 23  ulterieurement        creatifs          cold
# 24         tresors         poupees        living
# 25       completer          decale        cobalt
# 26  identification           ratez    desactivee
# 27      autrichien      connectees  experimental
# 28      beneficiez         ampoule       texture
# 29             vin           staff       passive
#      Topic # 01        Topic # 02     Topic # 03      Topic # 04   Topic # 05  \
# 0   destination         infection        prefixe           grand     patinage
# 1        voyage          rougeole          tarif       politique      butagaz
# 2         petit       vaccination     telephoner         service     biathlon
# 3         plage          metrique        virtuel            jour  acrobatique
# 4         grand      synthetiques       composez           image         judo
# 5          beau         ponctuels       habituel           droit     suggerez
# 6       circuit              aire     economisez            type    criterium
# 7      voyageur        periodique     habituelle            mail   breakdance
# 8         ville        mammiferes      indicatif            date  phonetiques
# 9         guide          compteur        appelez     information      curling
# 10       hotels     topographique      operateur        nouvelle   skateboard
# 11      paysage           parlees       comparez         contact       karate
# 12       billet         fecondite     comparatif        location    bobsleigh
# 13         parc          natalite   telephonique            mort       rallye
# 14     meilleur             polar        appeler           sport         luge
# 15      voiture          routiere     fonctionne          source   adrenaline
# 16     pratique         infantile     operateurs          ancien   subjonctif
# 17        carte           rentree           fixe           homme        alpin
# 18     montagne              sida        facture         mention    alpinisme
# 19        photo   alphabetisation       portable         legales     nordique
# 20       sejour         mortalite       proposes    gouvernement      masters
# 21      vacance          createur   conversation          action        greco
# 22         nuit          urbaines     angleterre          groupe         surf
# 23       agence          hepatite  immediatement   international         jeep
# 24     aventure     centrifugeuse  correspondant        position       hockey
# 25       partir  environnementale         orange  internationale     handball
# 26    assurance         moustique          allez         contenu          ski
# 27        hotel           placard     ordinateur            plan      maillet
# 28         iles        internaute          siege            code       aviron
# 29        route           aliment          devez      population         boxe
#
#         Topic # 06   Topic # 07     Topic # 08    Topic # 09
# 0             yuan        range         finale         edito
# 1            xiang   suggestion       protegee  encyclopedie
# 2             tong       module         joueur     epilateur
# 3             yang   transition        tracage    extracteur
# 4             chou        promo   organisateur         apnee
# 5             fang        label      deployons    controleur
# 6             gong         mime     recherchez       stretch
# 7             tian    visionner   conformement         loyer
# 8            adobe       tester       utilises         plume
# 9             ding   multiplier       relative        brevet
# 10            gang  automatique         entrez     connectee
# 11            dong       format      diaporama         layer
# 12            song       fusion       palmares       sommeil
# 13            pian       finish      propriete    comparatif
# 14            ming        noise      efforcons      figurant
# 15            bing        event   intellectuel          tuer
# 16            chao        probe       inegales    succession
# 17            bang       kevlar         navaja      depeches
# 18            juan       bumper     convention     nutrition
# 19            kids        drift       aiderons        square
# 20            miao        jumbo  participation        figaro
# 21            chai      message      amethyste         impot
# 22            long       sample          coupe         mythe
# 23            page       factor       football    olympiques
# 24            rang     regarder     formulaire    contextuel
# 25  transnationaux      affiche      finaliste        revenu
# 26       naissance        octet    competentes        timing
# 27        revetues         opus         reunie          pack
# 28       industrie         lues          catch         seuil
# 29            info   actualisez           cocu    prospectif
#      Topic # 01        Topic # 02     Topic # 03     Topic # 04  \
# 0   destination         infection        prefixe          grand
# 1        voyage          rougeole          tarif      politique
# 2         plage          metrique     telephoner        service
# 3         petit      synthetiques        virtuel           jour
# 4       circuit              aire       composez          image
# 5          beau         ponctuels       habituel          droit
# 6         grand        periodique     habituelle           type
# 7      voyageur          compteur     economisez           mail
# 8         guide        mammiferes      indicatif    information
# 9         ville     topographique        appelez           date
# 10      paysage         fecondite      operateur       nouvelle
# 11       hotels           parlees       comparez        contact
# 12         parc          natalite     comparatif       location
# 13       billet             polar   telephonique        mention
# 14     montagne         infantile        appeler        legales
# 15     pratique          urbaines     fonctionne          petit
# 16      voiture          routiere     operateurs         ancien
# 17       sejour           rentree        facture         source
# 18     aventure              sida       portable           mort
# 19       agence   alphabetisation       proposes          homme
# 20      vacance         mortalite   conversation       position
# 21        photo          createur     angleterre          sport
# 22    assurance  environnementale           fixe           plan
# 23        carte        internaute  immediatement       meilleur
# 24     meilleur     centrifugeuse  correspondant         action
# 25       partir          vocation          allez         groupe
# 26         nuit             biais         orange           lien
# 27  inspiration           placard     ordinateur     population
# 28        hotel         concombre          siege        content
# 29      sejours           carotte          devez  international
#
#          Topic # 05      Topic # 06      Topic # 07    Topic # 08  \
# 0             avers       champagne           jouet         xiang
# 1          gauloise        archivez        parisien          fang
# 2    merovingiennes  kinesitherapie        conclure          chou
# 3            pomelo          tesson        commande          bang
# 4       framboisier          cuvees          ecrire          tong
# 5         sapotille           logue         manette          yuan
# 6            mombin   irresistibles       publiques          ding
# 7           surette        vigneron           marne          yang
# 8    fructification     generaliste      aspirateur          gang
# 9         groseille      astronomie      intertitre          pian
# 10        fruitiere            anon         affiche          dong
# 11  encyclopediques          tentez          optant         adobe
# 12           goyave           gerez      disposerez          ming
# 13         perennes         moderee           scene          song
# 14   comprehensions        exclusif   reconditionne        finale
# 15           cadran    arborescence  electromenager          gong
# 16    entrecroisees         detecte        cloturer          bing
# 17        plagiaire           bulle         jouable          kids
# 18        chataigne       remporter    puericulture          tian
# 19        attirions           ancre        referent          rang
# 20        levitique      renseignez      surchauffe          chao
# 21        ephesiens         achetez       eligibles      protegee
# 22          encadra          madere       reveillon        joueur
# 23          stylisa      autrichien     marseillais          ahan
# 24      dispatching       completer          decale          zzzz
# 25         aiderent  identification         liseuse          flan
# 26             esse         tresors           serre          futs
# 27           tonner          degree        chaudron    recherchez
# 28          citrine  ulterieurement            nerf      relative
# 29       ornemental      beneficiez            lego  conformement
#
#      Topic # 09    Topic # 10
# 0         range         arabe
# 1    suggestion       tcheque
# 2        module        revenu
# 3    transition         seuil
# 4     distiller  encyclopedie
# 5         label     epilateur
# 6        format       roumain
# 7           set      slovaque
# 8         promo    extracteur
# 9        decode      polonais
# 10        event         apnee
# 11  automatique          turc
# 12      content    controleur
# 13       finish       stretch
# 14        octet        coreen
# 15         cold         japon
# 16       expire        danois
# 17         lues       bulgare
# 18        noise    vietnamien
# 19     fraction     islandais
# 20        probe       chinois
# 21       kevlar      figurant
# 22        jumbo    traduction
# 23       bumper     connectee
# 24       sample        letton
# 25         opus      hongrois
# 26        drift       suedois
# 27       factor      espagnol
# 28       living   neerlandais
# 29         apis          pack
#      Topic # 01     Topic # 02     Topic # 03   Topic # 04     Topic # 05  \
# 0   destination  centrifugeuse        prefixe        grand         pleyel
# 1        voyage        placard          tarif      service        exhumer
# 2         plage      concombre     telephoner    politique     abdominaux
# 3         petit        carotte       composez        image   degoulinants
# 4       circuit         goutte        virtuel         jour      polyester
# 5          beau       terminal       habituel         mail  necrologiques
# 6      voyageur        butagaz     economisez         type      prefacier
# 7         grand        vitesse     habituelle        droit         cadran
# 8         ville     breakdance      indicatif         date      decennale
# 9         guide         broyer        appelez      contact       margelle
# 10       hotels         purees      operateur     nouvelle       enflamma
# 11      paysage     processeur       comparez     meilleur     textuelles
# 12       billet        brocoli     comparatif  information        genuine
# 13         parc        curling   telephonique        sport          huart
# 14     pratique          strip        appeler        petit         ivraie
# 15      voiture     skateboard     fonctionne      mention       malefice
# 16        carte         karate     operateurs     location      spherique
# 17     montagne         broyes        facture      legales     pentathlon
# 18       sejour      bobsleigh       portable       ancien     mousseline
# 19       agence          smash       proposes     position           kadi
# 20    assurance        sideral   conversation         mort    comparaitra
# 21      vacance        obstrue     angleterre        homme       zodiaque
# 22     aventure     televiseur           fixe         body         muguet
# 23        photo        proline  immediatement         code          duper
# 24       partir      criterium  correspondant       source  retransmettra
# 25     meilleur       obstruer          allez      content         petale
# 26         iles     centrifuge         orange       compte           esse
# 27  inspiration        genants     ordinateur       groupe          emaux
# 28         nuit      carambole          siege      contenu           epis
# 29        hotel         persil          devez  commentaire       empressa
#
#         Topic # 06   Topic # 07      Topic # 08 Topic # 09      Topic # 10  \
# 0           editos        range           comma       yuan     vaccination
# 1        champagne   suggestion            shed      xiang       infection
# 2             quiz       module         inversa       tong         maladie
# 3          extrade   transition       phoniques       yang          vaccin
# 4           debats        promo        spectral       chou       moustique
# 5         chantons        label     centraliser       fang          fievre
# 6       suspendent         mime      espacement       gong       diphterie
# 7          pelerin  automatique          prouva      adobe         tetanos
# 8     contestation    visionner  positionnement       ding        typhoide
# 9        phosphore   multiplier        commuter       tian     recommandee
# 10          bayard       tester   actualisation       dong       sanitaire
# 11           prion       fusion     crepuscules       gang            rage
# 12       reclusion       format        phonique       pian    poliomyelite
# 13      exposition     shopping         travees       ming        voyageur
# 14        rassures       finish         associa       song       paludisme
# 15  protestantisme      affiche      sagittaire       bing  transmissibles
# 16        archivez        brand        zodiaque       chao           virus
# 17        judaisme      message           gnome       bang          grippe
# 18  kinesitherapie        noise         boudoir       juan        hepatite
# 19          misent        probe        cornette       kids         morsure
# 20          tesson       kevlar       lactation       miao          dengue
# 21          assaut       bumper         tenebre       chai       symptomes
# 22          cuvees        event         patches       page   professionnel
# 23      orthodoxie        jumbo           pleur       rang    sexuellement
# 24           logue     regarder         tartane       long        medicaux
# 25   irresistibles        drift      engraisses       bold        rougeole
# 26       fantaisie       factor           lerot       cyan          risque
# 27        vigneron         edit          micron  distiller         aliment
# 28        retraite       sample    telecommande       info     consulaires
# 29     generaliste        octet      monochrome       sang         hygiene
#
#         Topic # 11
# 0      statistique
# 1     organisation
# 2        nationale
# 3         habitant
# 4       population
# 5       republique
# 6    developpement
# 7        politique
# 8            etats
# 9         officiel
# 10           unies
# 11     information
# 12     cooperation
# 13  internationale
# 14          sierra
# 15            mali
# 16          ivoire
# 17          guinee
# 18          revenu
# 19           arabe
# 20       esperance
# 21      economique
# 22          indice
# 23   administratif
# 24      croissance
# 25       industrie
# 26           benin
# 27     exportation
# 28    gouvernement
# 29             uni
#      Topic # 01      Topic # 02       Topic # 03   Topic # 04      Topic # 05  \
# 0   destination       infection          cocarde        grand     recupererez
# 1        voyage     vaccination           astral        image        feminise
# 2         petit       diphterie         etablira      service        sombrero
# 3         plage       moustique         remettra    politique       naviguiez
# 4         grand      coqueluche        inversees         jour       canebiere
# 5          beau  transmissibles      facultative         mail      engraisses
# 6      voyageur         tetanos       pharmacien         type       lactation
# 7       circuit        hepatite     prescription         date          garrot
# 8         ville    sexuellement         decharge        droit        snobisme
# 9         guide         maladie       ordonnance      contact          tarare
# 10      paysage            rage      vaccination     nouvelle        enfuyant
# 11        carte        typhoide          mesurez  information         ajustee
# 12       hotels         morsure         methanol        sport      pentathlon
# 13     pratique     universelle        medicales         mort        escalera
# 14       billet      contracter         flambees     location     repetiteurs
# 15         parc       paludisme        miniature      mention      etalonnage
# 16      voiture         sexuels         jugement      content     coordonnant
# 17       sejour     articulaire        paralysie     position        laitiere
# 18     montagne    intestinales        remplacer        homme         robuste
# 19     meilleur         cholera          malaria      legales          pesage
# 20        photo     consulaires         ingerees         body   retransmettra
# 21       agence          fievre     intoxication       ancien  interpellaient
# 22    assurance          vaccin          sponsor       source           sutra
# 23      vacance    poliomyelite  complementaires     meilleur         urinoir
# 24       partir          dengue      chronologie       compte      accouchant
# 25         iles    preservatifs            juree         info   manifesterait
# 26     aventure        diarrhee    fourmillement       action         situons
# 27         nuit         hygiene          inversa      contenu       disloquer
# 28        hotel       varicelle         medecine         code         minuter
# 29     tourisme     recommandee           toxine        petit           skaal
#
#         Topic # 06      Topic # 07 Topic # 08      Topic # 09      Topic # 10  \
# 0        champagne        parisien       yuan        flechies       emballage
# 1         archivez           jouet      xiang      apparaisse       affranchi
# 2   kinesitherapie        commande       tong        suggeree          timbre
# 3           tesson         manette       yang      redemarrer          grille
# 4           cuvees           marne       chou       raccourci       adressage
# 5            logue      intertitre       fang   experimentale    reexpedition
# 6         vigneron  electromenager       ding          speech        pochette
# 7    irresistibles        referent       gong           ferai      reexpedier
# 8      generaliste            slug      adobe      elargissez     relationnel
# 9       astronomie         affiche       tian           tapez        roulette
# 10            anon           ratez       pian           zoome           envoi
# 11          tentez           seine       dong      saisissant          payees
# 12         moderee        hippisme       gang         mentale         sticker
# 13           gerez       bricolage       song         cachees      affranchir
# 14        exclusif    immobilieres       ming         pluriel  collectionneur
# 15    arborescence          fusion       chao           verbe     procuration
# 16         detecte           opter       bing        associer        expedier
# 17       remporter         redoute       bang  successivement      simplifiez
# 18           bulle           swing       juan         activee      etiquettes
# 19           ancre          impots       kids  classification        marianne
# 20      renseignez          averer       miao    personnalise        reduisez
# 21         achetez           rater       chai     psychiatrie       securisez
# 22      autrichien          casque       cyan          appuie    demenagement
# 23          madere            deco       rang    victimologie       securises
# 24          editos           denis  distiller             ion       facilitez
# 25  identification          livrer       page         clavier        carterie
# 26       completer      aspirateur       bold    manipulation        vieillir
# 27         tresors           alias       long         requete     contractuel
# 28  ulterieurement        proposee    prefixe            nano           colis
# 29          degree        proverbe      tarif            cepe       livraison
#
#         Topic # 11    Topic # 12
# 0      statistique         range
# 1       population    suggestion
# 2     organisation        module
# 3         habitant    transition
# 4        politique         label
# 5        nationale         promo
# 6         officiel   automatique
# 7    developpement        format
# 8            etats         event
# 9       republique        finish
# 10    gouvernement        manage
# 11           unies         noise
# 12           arabe         probe
# 13  internationale        kevlar
# 14           droit        sample
# 15          revenu        bumper
# 16             uni         drift
# 17          nation         jumbo
# 18     cooperation        factor
# 19      economique          lues
# 20      croissance         octet
# 21         royaume          opus
# 22           union          cold
# 23         secteur    actualisez
# 24     exportation      eviction
# 25     information  experimental
# 26   administratif        living
# 27       esperance        cobalt
# 28          indice    desactivee
# 29            nord       texture
#      Topic # 01         Topic # 02 Topic # 03   Topic # 04      Topic # 05  \
# 0   destination             astral       yuan        image       numismate
# 1        voyage        facultative      xiang      service       collegial
# 2         petit           remettra       tong         mail           polit
# 3         plage           etablira       yang        grand         affirma
# 4         grand           decharge       chou         jour       implosion
# 5          beau        chronologie       fang         type       eliminons
# 6       circuit           methanol       ding         date      vingtiemes
# 7         ville           jugement       gong    politique    demontraient
# 8      voyageur          remplacer       tian        sport       emportent
# 9         guide          inversees      adobe      content   exploratoires
# 10      paysage           candides       pian      contact        aspirait
# 11     pratique            sponsor       dong     meilleur       livrerent
# 12     montagne        radioscopie       ming         mort        aneantit
# 13         parc            showbiz       gang     location          semeur
# 14        carte            sixties       chao         body  rigoureusement
# 15       hotels  electroacoustique       song      mention          tiedes
# 16       billet             gravez       bang        droit         mariste
# 17      voiture          paralysie       bing         info            nome
# 18        photo          marceline       juan     position        artefact
# 19       sejour            chancel       kids      legales    lithuanienne
# 20       agence             chorus       miao         code         fermons
# 21      vacance       intoxication       chai     nouvelle      pentathlon
# 22    assurance         synchrones       cyan  commentaire       temoignee
# 23     aventure        provocantes  distiller       source      rechappait
# 24       partir             agapes       rang        video        papotage
# 25     meilleur           murement       bold       mobile       stimulent
# 26         iles       autoportrait       long       compte        sonorise
# 27     tourisme              lieue       page      message        ciselure
# 28  inspiration           betisier    cocarde        offre         petales
# 29         nuit             tintin       zzzz      contenu           lippu
#
#         Topic # 06      Topic # 07     Topic # 08     Topic # 09  \
# 0        champagne        parisien           wali     operateurs
# 1         archivez           jouet       resolvez        prefixe
# 2           tesson        commande           rida          tarif
# 3   kinesitherapie         manette           teta     telephoner
# 4           cuvees      intertitre           gail       habituel
# 5            logue        referent           otai     habituelle
# 6    irresistibles  electromenager            rai        virtuel
# 7         vigneron           ratez           ciao       composez
# 8       astronomie         affiche           posa     economisez
# 9      generaliste        hippisme           gala       flechies
# 10            anon           staff           valu        appelez
# 11    arborescence       bricolage           cyan     apparaisse
# 12          tentez    immobilieres      debloquer          ferai
# 13         moderee           opter        terrien     redemarrer
# 14           gerez          casque           miao      indicatif
# 15        exclusif         redoute           aval       suggeree
# 16         detecte          averer           ange      operateur
# 17           bulle           marne      duplicate      retrouvez
# 18       remporter            deco        inversa  experimentale
# 19           ancre           swing           hote         speech
# 20      renseignez      aspirateur       resoudre       comparez
# 21      autrichien        proposee        oubliez     comparatif
# 22         achetez        proverbe           fade      raccourci
# 23          madere           alias      soumettre   telephonique
# 24  identification           rater        machine        appeler
# 25       completer          livrer        trouble     fonctionne
# 26           champ       connectee      challenge          tapez
# 27  ulterieurement    interessante           abri     elargissez
# 28         tresors      disposerez     phonologie     saisissant
# 29          degree          limite  exclusivement        mentale
#
#       Topic # 10      Topic # 11     Topic # 12    Topic # 13
# 0    vaccination      population       rachetes         range
# 1      ambassade    organisation        souriez    suggestion
# 2       consulat       politique       receptif        module
# 3           visa  internationale        stresse    transition
# 4        maladie   developpement    discourtois         label
# 5    consulaires       nationale        annules         promo
# 6       voyageur    gouvernement     sponsorise   automatique
# 7     consulaire      territoire   redactionnel        format
# 8          saint       ressource     illegalite         noise
# 9         sierra         secteur       atterrit         probe
# 10        panama         sociale     diversifie        kevlar
# 11     grenadine        habitant    liquidation        bumper
# 12    philippine      economique         blonde         jumbo
# 13        ivoire          nation         cerise         drift
# 14    dominicain     statistique  diffamatoires         event
# 15        vaccin        officiel     moderateur        factor
# 16         benin           etats      supprimes        finish
# 17       urgence           droit         citron          lues
# 18        chypre            mise       recharge        sample
# 19          mali          projet      injurieux         octet
# 20     infection           grand        limoges          cold
# 21      mongolie          membre      commentes          opus
# 22     passeport      republique        trophee    actualisez
# 23       conseil           civil         presse      eviction
# 24     sanitaire         rapport          notez        cobalt
# 25      saoudite          revenu       notifier       texture
# 26         malte       industrie          baril    desactivee
# 27  legalisation        objectif       emotions  experimental
# 28       grenade     agriculture          oncle        living
# 29      imprimer    independance   perturbation       passive
#      Topic # 01     Topic # 02     Topic # 03     Topic # 04    Topic # 05  \
# 0   destination    vaccination        prefixe          grand      patinage
# 1        voyage  centrifugeuse          tarif      politique      biathlon
# 2         petit        placard     telephoner        service       butagaz
# 3         plage      concombre      indicatif          image   acrobatique
# 4         grand        carotte       composez           jour          judo
# 5          beau         vaccin        virtuel          droit  justifiables
# 6         ville       apportez       habituel           type     criterium
# 7       circuit      infection     economisez           mail    breakdance
# 8      voyageur         causer     habituelle    information       curling
# 9         guide         goutte        appelez           date    skateboard
# 10     meilleur       terminal      operateur       nouvelle        karate
# 11      paysage      moustique       comparez        contact        rallye
# 12         parc         grippe     comparatif           mort     bobsleigh
# 13     montagne    articulaire   telephonique          homme    adrenaline
# 14       hotels        hesitez        appeler       location          luge
# 15        carte         astral     fonctionne         action         alpin
# 16         nuit          laver     operateurs        mention       masters
# 17       sejour       hepatite       portable         source      nordique
# 18       partir         fievre        facture          sport        hockey
# 19      vacance        aliment       proposes         ancien     alpinisme
# 20         iles       etablira   conversation        legales      handball
# 21       agence    facultative     angleterre         groupe          jeep
# 22        photo       remettra           fixe  international         greco
# 23     pratique       medicaux  immediatement        content          surf
# 24         jour          polio  correspondant           plan          boxe
# 25     aventure        fournie          allez       position           ski
# 26      voiture        sponsor         orange   gouvernement      tactique
# 27       billet      inversees     ordinateur        contenu       trophee
# 28        hotel     pharmacien          siege         compte     franchise
# 29       nature      varicelle          devez           lien       combine
#
#         Topic # 06      Topic # 07     Topic # 08       Topic # 09  \
# 0        champagne           jouet         finale           insert
# 1         archivez        parisien       protegee       apparaitre
# 2   kinesitherapie        commande         joueur        partagees
# 3           tesson         manette     recherchez   materiellement
# 4           cuvees            asse   conformement      portabilite
# 5            logue         affiche       relative        indemnite
# 6         vigneron      aspirateur         entrez            forum
# 7    irresistibles      disposerez   organisateur    referencement
# 8      generaliste    puericulture       utilises           saisie
# 9       astronomie      intertitre      diaporama         adequate
# 10          tentez            lego      propriete         hachette
# 11            anon   reconditionne       palmares        consentez
# 12           gerez            nerf   intellectuel          annonce
# 13         moderee         jouable     convention    indemnisation
# 14        exclusif       reveillon      deployons             saga
# 15    arborescence          optant          coupe       conservees
# 16           bulle       eligibles       football         publiees
# 17         detecte        cloturer      efforcons           mettra
# 18       remporter      surchauffe     formulaire          routard
# 19           ancre        chaudron       inegales         editeurs
# 20      renseignez         liseuse  participation  responsabilites
# 21         achetez     marseillais          catch          ecrivez
# 22          madere        referent    statistique          ecoutez
# 23      autrichien  electromenager       aiderons    rectification
# 24       completer          decale        element     consentement
# 25           champ           ratez         oeuvre        directive
# 26  identification         poupees          terme     accompagnent
# 27          degree         ampoule         reunie        compagnon
# 28      beneficiez        creatifs       pionnier         adresser
# 29         tresors      connectees    competentes        controles
#
#         Topic # 10     Topic # 11    Topic # 12   Topic # 13 Topic # 14
# 0        grenadine         revenu         range  recupererez       yuan
# 1           sierra      esperance    suggestion     precheur      xiang
# ...
# 1             forum          tesson      population       subjonctif
# 2         assurance  kinesitherapie       nationale         suggerez
# 3    materiellement      astronomie    organisation        associons
# 4         partagees        vigneron        habitant      phonetiques
# 5       portabilite        archivez   developpement     abreviations
# 6     referencement     generaliste           unies            lotta
# 7         indemnite        exclusif     exportation          abusive
# 8          adequate         moderee      croissance          defende
# 9          hachette           logue         domaine  inaccessibilite
# 10          voiture          cuvees         secteur          publico
# 11        consentez   irresistibles          indice          parrain
# 12          routard            anon       esperance         signalez
# 13      inspiration           ancre       industrie          reforma
# 14         publiees          tentez     cooperation            posez
# 15           mettra           bulle      republique           french
# 16       conservees        longueur     agriculture             vote
# 17    indemnisation    arborescence  internationale     travailleuse
# 18     accompagnent       remporter       ressource           contra
# 19          ecrivez           champ        objectif         eventuel
# 20         editeurs           gerez    gouvernement           portal
# 21          ecoutez         detecte       politique    inaccessibles
# 22             saga    destinataire     gouvernance         exprimes
# 23    rectification       completer   administratif          defendu
# 24        compagnon           servi         sociale          mailing
# 25  responsabilites      autrichien            taux            forma
# 26         adresser  identification          nation          devenez
# 27       apparaitre          madere           union        demandons
# 28        directive     deconnecter    independance             book
# 29          annonce          restez         rapport            agree
#
#        Topic # 13     Topic # 14     Topic # 15      Topic # 16  \
# 0       pronostic         finale       annuaire        chantons
# 1          pariez         joueur     croisieres  protestantisme
# 2            turf       protegee         billet           prion
# 3          parier   conformement     dominicain      suspendent
# 4    signaletique      diaporama     philippine       phosphore
# 5     symbolisant     recherchez         voyage         pelerin
# 6        dominion       relative       voyageur          bayard
# 7        encercle   intellectuel         chypre       reclusion
# 8     championnat      propriete    vaccination        judaisme
# 9           poker         entrez       equateur         extrade
# 10         hockey          coupe  neerlandaises        rassures
# 11       commenca       palmares          benin      orthodoxie
# 12        formant   organisateur       comparez    catholicisme
# 13       handball       utilises          heure          misent
# 14          ratio     convention          malte            haie
# 15        trinite       football           visa      ecosysteme
# 16          saint     formulaire      argentine           bible
# 17        etablit  participation          chili       fantaisie
# 18      grenadine          catch         guinee        retraite
# 19    secretariat    statistique         ivoire      rigoureuse
# 20  appartiennent         oeuvre          perou         doublee
# 21          globe        element    hebergement         laicite
# 22        etendue          terme          meteo      bouddhisme
# 23        grenade     historique       saoudite        argentin
# 24   independants        envoyer         panama         exporte
# 25   competitions          juree         bottin         reperes
# 26       autonome         equipe         bresil           milan
# 27        amicaux           tour    equatoriale          editos
# 28         sierra          match          ville            pape
# 29         guinee         niveau       belgique       exclusion
#
#         Topic # 17  Topic # 18    Topic # 19
# 0      vaccination        yuan         range
# 1        infection       xiang    suggestion
# 2          maladie        tong        module
# 3           vaccin        yang         label
# 4        moustique        chou    transition
# 5          tetanos       adobe         promo
# 6        diphterie        fang        format
# 7           fievre        gong         event
# 8         typhoide        tian   automatique
# 9        sanitaire        ding        finish
# 10    poliomyelite        gang        action
# 11  transmissibles   epilateur         noise
# 12       paludisme        dong         probe
# 13            rage      revenu        sample
# 14           virus       apnee       message
# 15        hepatite  extracteur        bumper
# 16         aliment     stretch        kevlar
# 17    sexuellement        ming        factor
# 18         morsure        song         jumbo
# 19          risque  controleur         drift
# 20     recommandee        juan          lues
# 21         hygiene        pian  experimental
# 22          dengue        bang        manage
# 23       ambassade       loyer         octet
# 24         piqures        chao          opus
# 25     consulaires        bing    desactivee
# 26    moustiquaire       plume        living
# 27       passeport      brevet      feedback
# 28      coqueluche        pack       passive
# 29          grippe     sommeil    actualisez
#         Topic # 01 Topic # 02     Topic # 03   Topic # 04      Topic # 05  \
# 0           billet  debloquer        prefixe       voyage  merovingiennes
# 1      inspiration   resolvez          tarif        petit           avers
# 2            forum  duplicate     telephoner        grand        feodales
# 3          voiture       teta       composez  destination     transmettez
# 4        assurance       rida        virtuel     meilleur          ciblez
# 5      transmettre       gail       habituel        image      monetaires
# 6      destination  soumettre     economisez        ville       deference
# 7          aeriens       wali     habituelle         mail           banjo
# 8         aventure       otai      indicatif         jour      animalerie
# 9   materiellement        rai        appelez         info       computers
# 10   referencement       ciao      operateur         beau          patine
# 11     portabilite    trouble       comparez        guide         audible
# 12        hachette  challenge   telephonique         type        echangez
# 13       indemnite       posa     comparatif         date         demange
# 14         routard       cyan        appeler  information       luminaire
# 15        voyageur       gala     fonctionne      contact           usuel
# 16       consentez     danger     operateurs     location         usuelle
# 17        adequate      robot        facture        event    puericulture
# 18        pratique       valu       portable        photo      calculette
# 19          mettra    terrien       proposes        carte          usuels
# 20       partagees       miao   conversation       option      lateralite
# 21           utile      natif     angleterre        plage           tokay
# 22   indemnisation       aval           fixe      service         minette
# 23           livre      input  immediatement        offre         epousez
# 24         ecrivez      trace  correspondant         voir        malefice
# 25      conservees       ange          allez        saint        droitier
# 26           guide   resoudre         orange         nuit    enregistreur
# 27        publiees       hote     ordinateur    condition        rainette
# 28    accompagnent    oubliez          siege        style        gauloise
# 29          voyage       fade      retrouvez         prix       rebaptisa
#
#         Topic # 06      Topic # 07 Topic # 08      Topic # 09      Topic # 10  \
# 0        champagne           jouet       yuan       raccourci     vaccination
# 1         exclusif        parisien      xiang        flechies       infection
# 2         archivez        commande       tong      apparaisse         maladie
# 3   kinesitherapie         manette       yang      redemarrer          vaccin
# 4           tesson         affiche       chou        suggeree       moustique
# 5            logue      aspirateur       fang   experimentale     recommandee
# 6            champ      intertitre       gong           ferai       diphterie
# 7           cuvees            club       ding           tapez          fievre
# 8    irresistibles      disposerez       tian          speech         tetanos
# 9       astronomie   reconditionne      adobe      elargissez        typhoide
# 10     generaliste        referent       gang  successivement  transmissibles
# 11        vigneron    puericulture       dong         mentale            rage
# 12            anon         jouable       pian           verbe    poliomyelite
# 13          tentez  electromenager       chao      saisissant       sanitaire
# 14           gerez       eligibles       ming         cachees    sexuellement
# 15         moderee          limite       song        associer       paludisme
# 16           bulle      surchauffe       bing         pluriel           virus
# 17    arborescence        cloturer       bang  classification        hepatite
# 18         detecte        chaudron       juan         requete          dengue
# 19       remporter          optant       kids         clavier         morsure
# 20           ancre         liseuse       miao    encyclopedie          grippe
# 21      autrichien     marseillais       chai          appuie        rougeole
# 22       completer       reveillon       rang         activee        medicaux
# 23  identification            lego       page    manipulation         aliment
# 24      renseignez           ratez       cyan      apparaitre       symptomes
# 25          degree            nerf  distiller           atlas         hygiene
# 26         achetez        hippisme       long         feminin   professionnel
# 27        palmares          podium       bold            chia         cholera
# 28            rail        creatifs       sang        exporter          risque
# 29          madere         poupees       zzzz          defaut         piqures
#
#         Topic # 11     Topic # 12     Topic # 13    Topic # 14     Topic # 15  \
# 0      statistique       flaneuse        cocarde         coupe          notez
# 1            arabe  concatenation      raccourci      palmares  centrifugeuse
# 2           sierra     dispatcher     subjonctif      football        carotte
# 3         habitant     rotisserie       suggerez        basket        placard
# 4           chypre        vicomte   abreviations       sportif      concombre
# 5            saint        residez    phonetiques         poker       rachetes
# 6        grenadine     reveillons        abusive        tennis        stresse
# 7           ivoire   conciergerie        parrain         rugby        souriez
# 8       population           pacs        mesurez      champion       receptif
# 9        esperance         puisez       signalez          foot        annules
# 10          guinee   construisons       eventuel     graphique     illegalite
# 11           benin       affectes          posez         score    discourtois
# 12            mali       marechal   alphabetique    calendrier         goutte
# 13          panama     absorption         portal    classement    liquidation
# 14         trinite           rial          oubli        joueur     sponsorise
# 15            sida      commandez       soutenez      cyclisme       terminal
# 16        saoudite          barbe        devenez         ligue   redactionnel
# 17          langue       eventail   amelioration      hippique       atterrit
# 18      philippine         moulin        command         match         cerise
# 19     equatoriale          jules          aidez        finale     diversifie
# 20      dominicain        comites        suedois    boursieres     moderateur
# 21        natalite         neutre          agree  defaillantes          oncle
# 22        mongolie       chaussee      miniature        regale      supprimes
# 23  centrafricaine       preferee        accorde        brunet         blonde
# 24       infantile          balte       masculin         verif      commentes
# 25       mortalite         aident  correspondent        dealer   perturbation
# 26       allemagne        cheques         manage      boursier  diffamatoires
# 27            aire       himalaya          these      courtier        trophee
# 28           japon        polaire         coreen         tries       recharge
# 29         grenade           rene        reverse        grille         citron
#
#           Topic # 16           Topic # 17    Topic # 18    Topic # 19  \
# 0         gouvernant          recupererez        revenu         range
# 1          renvoient                amibe     epilateur    suggestion
# 2      presidentiels            emulation         apnee        module
# 3            renvoie       medicamenteuse    extracteur    transition
# 4        statistique          intestinale       stretch         label
# 5   institutionnelle               contre    controleur         promo
# 6          glossaire                fecal        brevet        format
# 7            langage             moutarde         loyer   automatique
# 8             redige             pistache         layer        finish
# 9            obtenez        elephantiasis         plume         event
# 10           etablis          diarrheique      figurant  documentaire
# 11         appliquee  conventionnellement    comparatif         probe
# 12          conclure               fraise       sommeil         noise
# 13        composante          chloroquine         promo        kevlar
# 14        biographie             devoilez        figaro          lues
# 15           variant               guelfe     connectee        bumper
# 16       chronologie            preetabli  encyclopedie         jumbo
# 17            cahier             egoutter     nutrition         drift
# 18     intermediaire           chataignes          tuer         octet
# 19      observatoire           proposions          pack        sample
# 20         recuperer      sensationnelles        square        factor
# 21          systemes            refroidir         impot          cold
# 22          recentes            gingembre    olympiques          opus
# 23              bold       preventivement         mythe        extras
# 24       transparent              collyre         flush    actualisez
# 25   supplementaires              refugia         vertu  experimental
# 26       precedentes              anchois       pointer        living
# 27           externe             saladier        burger       passive
# 28      proclamation            lactation         rugby      eviction
# 29            profil             vinaigre       journal     supprimee
#
#         Topic # 20
# 0        politique
# 1     gouvernement
# 2             mort
# 3            droit
# 4          service
# 5            grand
# 6            homme
# 7        president
# 8   internationale
# 9         ministre
# 10        economie
# 11       militaire
# 12           civil
# 13            jour
# 14          guerre
# 15         pouvoir
# 16         societe
# 17   international
# 18    organisation
# 19         science
# 20            chef
# 21      population
# 22        nouvelle
# 23       actualite
# 24         dossier
# 25         reforme
# 26         million
# 27          source
# 28      entreprise
# 29          ancien

# %%
topic_LDA_tourisme = [('LDA4',0),('LDA5',0),('LDA6',0),('LDA7',0),('LDA8',0),('LDA9',0),('LDA10',0),('LDA11',0),('LDA12',0),
                      ('LDA13',0), ('LDA14',0),('LDA15',0),('LDA16',0),('LDA17',0),('LDA18',0),('LDA20',3)]
topic_LDA_politique = [('LDA16',15),('LDA17',15),('LDA18',15),('LDA20',19)]
topic_LDA_religion = [('LDA17',16),('LDA19',15)]
topic_LDA_actu = [('LDA4',3),('LDA5',3),('LDA6',3),('LDA7',3),('LDA8',3),('LDA9',3),('LDA10',3),('LDA11',3),('LDA12',3),
                  ('LDA13',3),('LDA14',3),('LDA15',3),('LDA18',3)]
topic_LDA_sante = [('LDA11',9),('LDA12',1),('LDA15',1),('LDA17',9),('LDA18',16),('LDA19',16),('LDA20',9)]
topic_LDA_loisirs = [('LDA5',4),('LDA8',4),('LDA9',4),('LDA14',4),('LDA18',11),('LDA19',7),('LDA20',13)]
topic_LDA_stats = [('LDA12',10),('LDA13',10),('LDA14',10),('LDA15',10),('LDA18',10),('LDA19',10)]
topic_LDA_guides = [('LDA16',1),('LDA17',14),('LDA18',8),('LDA19',8),('LDA20',0)]

# %% [markdown]
# ## Fusion des listes de topics le cas échéant, et constitution d'un dico des sujets
# ### + module de vérification de la cohérence des sujets

# %%
topic_tourisme = topic_NMF_tourisme + topic_LDA_tourisme
topic_religion = topic_NMF_religion + topic_LDA_religion
topic_stats = topic_NMF_stats + topic_LDA_stats
topic_politique = topic_NMF_politique + topic_LDA_politique
topic_guides = topic_NMF_guides + topic_LDA_guides

# %%
topics = {'tourisme':topic_tourisme,'religion':topic_religion,'stats':topic_stats, 'guides':topic_guides,
          'politique':topic_politique,'NMF_reservations':topic_NMF_reservations,'NMF_consulat':topic_NMF_consulat,
          'LDA_actu':topic_LDA_actu,'LDA_sante':topic_LDA_sante,'LDA_loisirs':topic_LDA_loisirs}

# %%
def verif_listes(liste):
    word_dict = {}
    
    for i in range(len(liste)):
        cluster = liste[i][0]
        col = liste[i][1]
        model = load(cluster+'.joblib')
        feat_names = model.named_steps['tfidf'].get_feature_names()
        words_ids = model.named_steps['clust'].components_[col].argsort()[:-30 - 1:-1]
        words = [feat_names[key] for key in words_ids]
        word_dict[cluster.format(i+1)] = words
    return pd.DataFrame(word_dict)
verif_listes(topic_LDA_loisirs)
# Out:
#                  LDA5         LDA8         LDA9         LDA14         LDA18  \
# 0             butagaz     patinage     patinage      patinage        basket
# 1            suggerez      butagaz      butagaz      biathlon         rugby
# 2            patinage     biathlon     biathlon       butagaz         poker
# 3              karate  acrobatique  acrobatique   acrobatique     graphique
# 4          breakdance     suggerez         judo          judo      champion
# 5           criterium         judo     suggerez  justifiables       sportif
# 6          skateboard    criterium    criterium     criterium        tennis
# 7           bobsleigh   breakdance   breakdance    breakdance          foot
# 8             curling      curling  phonetiques       curling    calendrier
# 9            biathlon   skateboard      curling    skateboard         score
# 10        recupererez       karate   skateboard        karate         coupe
# 11         adrenaline    bobsleigh       karate        rallye         ligue
# 12        acrobatique       rallye    bobsleigh     bobsleigh      cyclisme
# 13               judo  recupererez       rallye    adrenaline      hippique
# 14               luge   adrenaline         luge          luge    boursieres
# 15            maillet         luge   adrenaline         alpin      palmares
# 16          alpinisme        alpin   subjonctif       masters  defaillantes
# 17  gravitationnelles       hockey        alpin      nordique        brunet
# 18             rallye    alpinisme    alpinisme        hockey    classement
# 19          naviguiez     handball     nordique     alpinisme        regale
# 20            ecuries      masters      masters      handball        dealer
# 21          corrobora     nordique        greco          jeep         verif
# 22            antonin         surf         surf         greco      football
# 23         subjonctif         jeep         jeep          surf      boursier
# 24              greco        greco       hockey          boxe         tries
# 25              alpin          ski     handball           ski      courtier
# 26                ski      maillet          ski      tactique      handball
# 27             jobard       aviron      maillet       trophee     dividende
# 28      metallisation     tactique       aviron     franchise          mati
# 29               surf      antonin         boxe       combine        hockey
#
#           LDA19         LDA20
# 0      patinage         coupe
# 1      biathlon      palmares
# 2       butagaz      football
# 3          judo        basket
# 4   acrobatique       sportif
# 5     criterium         poker
# 6        rallye        tennis
# 7    breakdance         rugby
# 8       curling      champion
# 9    skateboard          foot
# 10    bobsleigh     graphique
# 11       karate         score
# 12       hockey    calendrier
# 13      masters    classement
# 14     handball        joueur
# 15         luge      cyclisme
# 16   adrenaline         ligue
# 17     nordique      hippique
# 18        alpin         match
# 19        greco        finale
# 20         jeep    boursieres
# 21         boxe  defaillantes
# 22      trophee        regale
# 23    alpinisme        brunet
# 24     tactique         verif
# 25    franchise        dealer
# 26     feminine      boursier
# 27       sombre      courtier
# 28          ski         tries
# 29   artistique        grille

# %%
liste_mots = verif_listes(topic_LDA_precautions)
liste_mots = list(liste_mots[liste_mots.columns[0]])

# %% [markdown]
# ## Appel de la base de pages web

# %%
base.head()
# Out:
#    Unnamed: 0  Date_debut    Date_fin            Pays  Rang  \
# 0           0  2010-01-01  2010-12-31  Afrique du Sud     0
# 1           1  2010-01-01  2010-12-31  Afrique du Sud     1
# 2           2  2010-01-01  2010-12-31  Afrique du Sud     2
# 3           3  2010-01-01  2010-12-31  Afrique du Sud     3
# 4           4  2010-01-01  2010-12-31  Afrique du Sud     4
#
#                                            Liste_URL  \
# 0  http://www.slate.fr/story/26143/afrique-du-sud...
# 1  https://www.geo.fr/voyage/voyage-en-afrique-du...
# 2         http://plus.lefigaro.fr/tag/afrique-du-sud
# 3  https://www.quandpartir.com/meteo/afrique-du-s...
# 4  https://www.franceculture.fr/histoire/lafrique...
#
#                                         Contenu_page  \
# 0  googletag cmd push function     googletag disp...
# 1  sprite symbol usage  display  none        spri...
# 2  fig header  figh  full  fig header  collapsed ...
# 3  abonnement aux bons plans voyage              ...
# 4  programmespodcastsactualitessavoirsart et crea...
#
#                                         Mots_retenus  \
# 0  ['issue', 'peche', 'chair', 'partage', 'eclips...
# 1  ['salade', 'peche', 'recherchees', 'ancien', '...
# 2  ['trimestre', 'archeveque', 'veteran', 'lutte'...
# 3  ['remontant', 'devises', 'tableau', 'antilopes...
# 4  ['part', 'derivee', 'roche', 'rush', 'bain', '...
#
#                                            Mots_lemm
# 0  issue peche chair partage eclipse uni verre ta...
# 1  salade peche recherchees ancien nombre photo p...
# 2  trimestre archeveque veteran lutte moi site ch...
# 3  remontant devise tableau antilope active catch...
# 4  part derivee roche rush bain dura etoile piece...

# %%
base.drop(['Unnamed: 0'], axis = 1, inplace = True)
base = base.reset_index(drop = True)
base.head()
# Out:
#    Date_debut    Date_fin            Pays  Rang  \
# 0  2010-01-01  2010-12-31  Afrique du Sud     0
# 1  2010-01-01  2010-12-31  Afrique du Sud     1
# 2  2010-01-01  2010-12-31  Afrique du Sud     2
# 3  2010-01-01  2010-12-31  Afrique du Sud     3
# 4  2010-01-01  2010-12-31  Afrique du Sud     4
#
#                                            Liste_URL  \
# 0  http://www.slate.fr/story/26143/afrique-du-sud...
# 1  https://www.geo.fr/voyage/voyage-en-afrique-du...
# 2         http://plus.lefigaro.fr/tag/afrique-du-sud
# 3  https://www.quandpartir.com/meteo/afrique-du-s...
# 4  https://www.franceculture.fr/histoire/lafrique...
#
#                                         Contenu_page  \
# 0  googletag cmd push function     googletag disp...
# 1  sprite symbol usage  display  none        spri...
# 2  fig header  figh  full  fig header  collapsed ...
# 3  abonnement aux bons plans voyage              ...
# 4  programmespodcastsactualitessavoirsart et crea...
#
#                                         Mots_retenus  \
# 0  ['issue', 'peche', 'chair', 'partage', 'eclips...
# 1  ['salade', 'peche', 'recherchees', 'ancien', '...
# 2  ['trimestre', 'archeveque', 'veteran', 'lutte'...
# 3  ['remontant', 'devises', 'tableau', 'antilopes...
# 4  ['part', 'derivee', 'roche', 'rush', 'bain', '...
#
#                                            Mots_lemm
# 0  issue peche chair partage eclipse uni verre ta...
# 1  salade peche recherchees ancien nombre photo p...
# 2  trimestre archeveque veteran lutte moi site ch...
# 3  remontant devise tableau antilope active catch...
# 4  part derivee roche rush bain dura etoile piece...

# %% [markdown]
# ## Fonctions de vectorisation et de PCA
# ### puis appel de ces fonctions pour affecter une unique note par sujet et par page

# %%
def get_vectors(liste, colonne):
    labels_dict = {}
    for i in range(len(liste)):
        cluster = liste[i][0]
        col = liste[i][1]
        modele = load(cluster+'.joblib')
        labels = modele.transform(colonne)
        labels_dict[cluster.format(i+1)] = labels.T[col]
    return pd.DataFrame(labels_dict)

def pca(liste_labels, theme):
    pca = PCA(n_components=1)
    principalComponents = pca.fit_transform(liste_labels)
    principalDf = pd.DataFrame(data = principalComponents
                 ,columns = [theme])
    return principalDf

# %%
dico_pca = {}
i = 0
for key, value in topics.items():
    labels = get_vectors(value, base.Mots_lemm)
    labels_pca = pca(labels, key)
    dico_pca[key.format(i+1)] = labels_pca[labels_pca.columns[0]]
    print(key)
resultat_pca = pd.DataFrame(dico_pca)

# %%
resultat_pca.head()
# Out:
#    tourisme  religion     stats    guides  politique  NMF_reservations  \
# 0  0.062471 -0.021405 -0.051825 -0.033401   0.008573         -0.021258
# 1  1.114806 -0.014190 -0.175187  0.004551  -0.295525         -0.021258
# 2 -0.680977  0.005013 -0.170580 -0.034765   0.102804         -0.001779
# 3  2.671717 -0.020849 -0.171556 -0.025353  -0.423784          0.010535
# 4 -0.641960  0.017609 -0.020340 -0.030954   0.200690         -0.021258
#
#    NMF_consulat  LDA_actu  LDA_sante  LDA_loisirs
# 0     -0.006786 -0.201719   0.015992    -0.008494
# 1     -0.006786  0.762318  -0.020294    -0.007330
# 2     -0.003910 -0.865138  -0.015623    -0.004119
# 3      0.000363  2.224482  -0.020168    -0.007244
# 4     -0.006786 -0.868004  -0.020281    -0.006638

# %% [markdown]
# ## Traitement base
# - conversion des dates
# - création de colonnes contenant les scores par sujet
# - export de la base obtenue

# %%
base["Annee"] = [datetime.strptime(x, '%Y-%m-%d').year for x in base.Date_debut]
base.drop(['Date_debut','Date_fin'], inplace = True, axis = 1)
base.head()
# Out:
#              Pays  Rang                                          Liste_URL  \
# 0  Afrique du Sud     0  http://www.slate.fr/story/26143/afrique-du-sud...
# 1  Afrique du Sud     1  https://www.geo.fr/voyage/voyage-en-afrique-du...
# 2  Afrique du Sud     2         http://plus.lefigaro.fr/tag/afrique-du-sud
# 3  Afrique du Sud     3  https://www.quandpartir.com/meteo/afrique-du-s...
# 4  Afrique du Sud     4  https://www.franceculture.fr/histoire/lafrique...
#
#                                         Contenu_page  \
# 0  googletag cmd push function     googletag disp...
# 1  sprite symbol usage  display  none        spri...
# 2  fig header  figh  full  fig header  collapsed ...
# 3  abonnement aux bons plans voyage              ...
# 4  programmespodcastsactualitessavoirsart et crea...
#
#                                         Mots_retenus  \
# 0  ['issue', 'peche', 'chair', 'partage', 'eclips...
# 1  ['salade', 'peche', 'recherchees', 'ancien', '...
# 2  ['trimestre', 'archeveque', 'veteran', 'lutte'...
# 3  ['remontant', 'devises', 'tableau', 'antilopes...
# 4  ['part', 'derivee', 'roche', 'rush', 'bain', '...
#
#                                            Mots_lemm  Annee
# 0  issue peche chair partage eclipse uni verre ta...   2010
# 1  salade peche recherchees ancien nombre photo p...   2010
# 2  trimestre archeveque veteran lutte moi site ch...   2010
# 3  remontant devise tableau antilope active catch...   2010
# 4  part derivee roche rush bain dura etoile piece...   2010

# %%
base.drop(['Unnamed: 0'], inplace = True, axis = 1)

# %%
base['tourisme']=resultat_pca.tourisme
base['reservations']=resultat_pca.NMF_reservations
base['guides']=resultat_pca.guides
base['consulat']=resultat_pca.NMF_consulat
base['politique']=resultat_pca.politique
base['actu']=resultat_pca.LDA_actu
base['stats']=resultat_pca.stats
base['religion']=resultat_pca.religion
base['loisirs']=resultat_pca.LDA_loisirs
base['sante']=resultat_pca.LDA_sante

# %%
base.sort_values(by = 'loisirs')
# Out:
#                 Pays  Rang                                          Liste_URL  \
# 1020         Comores    19  https://gallica.bnf.fr/ark:/12148/bpt6k5790328...
# 1644           Grèce    12  https://www.clio.fr/CHRONOLOGIE/chronologie_la...
# 2103          Israël    26  http://pythacli.chez-alice.fr/civilisations/is...
# 2417           Liban    13  https://www.clio.fr/chronologie/chronologie_le...
# 4716         Vanuatu    14             https://www.senat.fr/ga/ga89/ga89.html
# ...              ...   ...                                                ...
# 14069      Slovaquie    18  https://www.lequipe.fr/Football/match-direct/q...
# 12365  Liechtenstein    21  https://www.lequipe.fr/Football/match-direct/q...
# 12269       Lettonie    24  https://www.lequipe.fr/Football/match-direct/q...
# 12834     Monténégro    27  https://www.lequipe.fr/Football/match-direct/q...
# 14560   Turkménistan    21  https://www.lequipe.fr/Football/match-direct/q...
#
#                                             Contenu_page  \
# 1020   rappel de votre demande format de telechargeme...
# 1644   retour a la page d accueil           qui somme...
# 2103   israel et palestine  histoire du peuple hebreu...
# 2417   retour a la page d accueil           qui somme...
# 4716   var hasjs   function       var htmltag   docum...
# ...                                                  ...
# 14069  se connecter   creer un compte                ...
# 12365  se connecter   creer un compte                ...
# 12269  se connecter   creer un compte                ...
# 12834  se connecter   creer un compte                ...
# 14560  se connecter   creer un compte                ...
#
#                                             Mots_retenus  \
# 1020   ['demeles', 'observe', 'charrues', 'remontant'...
# 1644   ['demeles', 'strategie', 'rapprochant', 'livre...
# 2103   ['annexion', 'provocations', 'vieil', 'liberes...
# 2417   ['dissout', 'annexion', 'liberes', 'chargees',...
# 4716   ['chargees', 'ancien', 'sortant', 'valeurs', '...
# ...                                                  ...
# 14069  ['gestion', 'explore', 'lutte', 'handball', 'i...
# 12365  ['gestion', 'explore', 'lutte', 'handball', 'i...
# 12269  ['gestion', 'explore', 'lutte', 'handball', 'i...
# 12834  ['gestion', 'explore', 'lutte', 'handball', 'i...
# 14560  ['gestion', 'explore', 'lutte', 'handball', 'i...
#
#                                                Mots_lemm  Annee  tourisme  \
# 1020   demeles observe charrue remontant cotonnier st...   2010  0.007502
# 1644   demeles strategie rapprochant livre union fonc...   2010 -0.652113
# 2103   annexion provocation vieux liberes chargees im...   2010 -0.712175
# 2417   dissout annexion liberes chargees ancien vacan...   2010 -0.702846
# 4716   chargees ancien sortant valeur tremblement ten...   2010 -0.708931
# ...                                                  ...    ...       ...
# 14069  gestion explore lutte handball internationaux ...   2019 -0.683825
# 12365  gestion explore lutte handball internationaux ...   2019 -0.683372
# 12269  gestion explore lutte handball internationaux ...   2019 -0.683397
# 12834  gestion explore lutte handball internationaux ...   2019 -0.684613
# 14560  gestion explore lutte handball internationaux ...   2019 -0.683854
#
#        reservations    guides  consulat  politique      actu     stats  \
# 1020      -0.021258 -0.015334 -0.006380   0.041024 -0.198872  0.072931
# 1644      -0.021258 -0.033653 -0.006786   0.512890 -0.797238  0.228766
# 2103      -0.021258 -0.034226 -0.005107   0.531915 -0.919915  0.085054
# 2417      -0.021258 -0.037828 -0.006786   0.627321 -0.843418  0.253454
# 4716      -0.020687 -0.042370  0.018062   0.503352 -0.829751  0.360419
# ...             ...       ...       ...        ...       ...       ...
# 14069     -0.021258 -0.037032 -0.006786  -0.421478 -0.371867 -0.171915
# 12365     -0.021258 -0.036991 -0.006786  -0.421437 -0.360507 -0.171861
# 12269     -0.021258 -0.036991 -0.006786  -0.421436 -0.360453 -0.171860
# 12834     -0.021258 -0.037032 -0.006786  -0.421475 -0.370296 -0.171915
# 14560     -0.021049 -0.036892 -0.006707  -0.421367 -0.345734 -0.171729
#
#        religion   loisirs     sante
# 1020  -0.017180 -0.011406  0.017830
# 1644   0.009257 -0.011332 -0.022449
# 2103   0.021042 -0.011168 -0.020049
# 2417   0.010617 -0.011163 -0.021728
# 4716  -0.017443 -0.011153 -0.025853
# ...         ...       ...       ...
# 14069 -0.012938  1.011905  0.084758
# 12365 -0.012713  1.014422  0.087409
# 12269 -0.012628  1.014689  0.087440
# 12834 -0.013031  1.019929  0.084694
# 14560 -0.013114  1.022612  0.089973
#
# [21431 rows x 17 columns]

# %%
base.drop('Mots_retenus', inplace = True, axis = 1)

# %%
base.to_csv('base_avec_pcaV2.csv')

# %%
base.to_json('base_avec_pcaV2.json')
